# %% [markdown]
# # Imports and setup

# %% [markdown]
# ### Auto-re-import python modules, useful for editing local files

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
import itertools
import logging
import os
import warnings
from collections import Counter

import matplotlib as mpl
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
from tqdm import tqdm

logging.basicConfig(level=logging.INFO)

pl.Config.set_verbose()
# mpl.rcParams["figure.max_open_warning"] = 0

from notifications import notify, notify_done
from scop_constants import n_scop_cols, same_scop_cols
from sourmash_constants import sourmash_score_cols

# %%
pl.__version__
# Out:
# '1.9.0'

# %% [markdown]
# # Read in data

# %%
! aws s3 sync --exclude '*' --include '*hp.k1*.filtered.pq' \
    --dryrun \
    s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp \
    /home/ec2-user/data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp
# Out:
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k10.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k10.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k11.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k11.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k12.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k12.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k13.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k13.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k14.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k14.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k15.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k15.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k16.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k16.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k17.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k17.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k18.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k18.filtered.pq
# (dryrun) download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k19.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k19.filtered.pq

# %%
! aws s3 sync --exclude '*' --include '*hp.k1*.filtered.pq' \
    s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp \
    /home/ec2-user/data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp
# Out:
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k14.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k14.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k13.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k13.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k15.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k15.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k17.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k17.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k16.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k16.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k18.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k18.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k19.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k19.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k12.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k12.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k11.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k11.filtered.pq
# download: s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k10.filtered.pq to ../../data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k10.filtered.pq

# %% [markdown]
# ## Iterate over all ksizes and moltypes

# %%
from sensitivity_until_first_false_positive_mem_optimized import (
    MultisearchSensitivityCalculator,
)

# %%
pl.scan_parquet('/home/ec2-user/data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k14.filtered.pq'

# %%
moltype_info = {
    # "protein": dict(
    #     ksizes=range(5, 21),
    #     pipeline_outdir="s3://seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-08__protein_k5-20",
    #     analysis_outdir="s3://seanome-kmerseek/scope-benchmark/analysis-outputs/protein",
    # ),
    # "dayhoff": dict(
    #     ksizes=range(5, 21),
    #     pipeline_outdir="s3://seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__dayhoff_k5-20",
    #     analysis_outdir="s3://seanome-kmerseek/scope-benchmark/analysis-outputs/dayhoff",
    # ),
    "hp": dict(
        ksizes=[14], #reversed(range(10, 16)),
        # pipeline_outdir="s3://seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__hp_k20-60",
        pipeline_outdir="/home/ec2-user/data/seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__hp_k20-60",
        # analysis_outdir="s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp",
        analysis_outdir="/home/ec2-user/data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp",
    ),
}

basename_template = r"scope40.multisearch.{moltype}.k{ksize}.filtered.pq"

for moltype, info in moltype_info.items():
    ksizes = info["ksizes"]
    cleaned_outdir = os.path.join(
        info["analysis_outdir"], "00_cleaned_multisearch_results"
    )
    sensitivity_outdir = os.path.join(
        info["analysis_outdir"], "01_sensitivity_until_first_false_positive"
    )
    if not os.path.exists(sensitivity_outdir):
        ! mkdir -p $sensitivity_outdir
    for ksize in ksizes:

        msc = MultisearchSensitivityCalculator(moltype, ksize, cleaned_outdir, sensitivity_outdir)
        msc.calculate_sensitivity()
# Out:
# INFO:notifications:Processing /home/ec2-user/data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/scope40.multisearch.hp.k14.filtered.pq with chunk size 10000
# INFO:notifications:Processing containment
#   0%|                                                                                                                                                                                        | 0/8396 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# Cell In[20], line 36
#      33 for ksize in ksizes:
#      35     msc = MultisearchSensitivityCalculator(moltype, ksize, cleaned_outdir, sensitivity_outdir)
# ---> 36     msc.calculate_sensitivity()
#
# File ~/2024-kmerseek-analysis/notebooks/sensitivity_until_first_false_positive_mem_optimized.py:129, in MultisearchSensitivityCalculator.calculate_sensitivity(self, sourmash_cols)
#     121 # Process data in chunks
#     122 for chunk_idx in tqdm(range(chunks)):
#     123     chunk = pl.scan_parquet(
#     124         self.in_pq,
#     125         schema=self.MULTISEARCH_SCHEMA,
#     126         row_index_name="row_count",
#     127         row_index_offset=chunk_idx * self.chunk_size,
#     128         n_rows=self.chunk_size,
# --> 129     ).collect()
#     131     if len(chunk) == 0:
#     132         continue
#
# File ~/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/polars/lazyframe/frame.py:2050, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2048 # Only for testing purposes
#    2049 callback = _kwargs.get("post_opt_callback", callback)
# -> 2050 return wrap_df(ldf.collect(callback))
#
# SchemaError: parquet file contained extra columns and no selection was given

# %%
# %debug
# Out:
# > /home/ec2-user/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/ipykernel/kernelbase.py(1325)_input_request()
#    1323                 # re-raise KeyboardInterrupt, to truncate traceback
#    1324                 msg = "Interrupted by user"
# -> 1325                 raise KeyboardInterrupt(msg) from None
#    1326             except Exception:
#    1327                 self.log.warning("Invalid Message:", exc_info=True)
# ipdb>  q

# %%
# sensitivity.show_graph()

# %%
# sensitivity.comm

# %%
sensitivity.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sensitivity.shape
#
# NameError: name 'sensitivity' is not defined

# %%
# g = sns.catplot(
#     data=sensitivity,
#     col="sourmash_score",
#     hue="ksize",
#     y="variable",
#     x="sensitivity",
#     col_wrap=4, height=3
# )

# %%
# %debug

# %%
cv
