# %% [markdown]
# # Imports and setup

# %% [markdown]
# ### Auto-re-import python modules, useful for editing local fils

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
import itertools

import matplotlib as mpl
import polars as pl
import seaborn as sns

# pl.Config.set_verbose(True)
# pl.Config.()
mpl.rcParams["figure.max_open_warning"] = 0

# Handwritten local modules
# import process_scop_sourmash_multisearch_polars
from process_scop_sourmash_multisearch_polars_mem_optimized import MultisearchParser

# %%
pl.__version__
# Out:
# '1.12.0'

# %%
pl.read_parquet_schema?
# Out:
# Signature: pl.read_parquet_schema(source: 'str | Path | IO[bytes] | bytes') -> 'dict[str, DataType]'
# Docstring:
# Get the schema of a Parquet file without reading data.
#
# Parameters
# ----------
# source
#     Path to a file or a file-like object (by "file-like object" we refer to objects
#     that have a `read()` method, such as a file handler like the builtin `open`
#     function, or a `BytesIO` instance).
#     For file-like objects,
#     stream position may not be updated accordingly after reading.
#
# Returns
# -------
# dict
#     Dictionary mapping column names to datatypes
# File:      ~/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/polars/io/parquet/functions.py
# Type:      function

# %% [markdown]
# # Read in data

# %%
analysis_outdir = (
    "s3://seanome-kmerseek/scope-benchmark/analysis-outputs/2024-10-09__protein_k5-20"
)

pipeline_outdir = (
    "s3://seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-08__protein_k5-20"
)
analysis_outdir
# Out:
# 's3://seanome-kmerseek/scope-benchmark/analysis-outputs/2024-10-09__protein_k5-20'

# %% [markdown]
# ## Read in one example file for schema

# %%
pq = "/home/ec2-user/data/seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__hp_k20-60/sourmash/multisearch/astral-scopedom-seqres-gd-sel-gs-bib-40-2.08.part_001.fa--in--astral-scopedom-seqres-gd-sel-gs-bib-40-2.08.part_001.fa.hp.10.multisearch.pq"

df = pl.scan_parquet(pq, n_rows=10)
df.schema
# Out:
# /tmp/ipykernel_12297/2035228567.py:4: PerformanceWarning: Resolving the schema of a LazyFrame is a potentially expensive operation. Use `LazyFrame.collect_schema()` to get the schema without this warning.
#   df.schema
# Schema([('query_name', String),
#         ('query_md5', String),
#         ('match_name', String),
#         ('match_md5', String),
#         ('containment', Float64),
#         ('max_containment', Float64),
#         ('jaccard', Float64),
#         ('intersect_hashes', Float64),
#         ('prob_overlap', Float64),
#         ('prob_overlap_adjusted', Float64),
#         ('containment_adjusted', Float64),
#         ('containment_adjusted_log10', Float64),
#         ('tf_idf_score', Float64)])

# %%
schema = df.schema.copy()
# schema["intersect_hashes"] = int
schema
# Out:
# /tmp/ipykernel_12297/3304229972.py:1: PerformanceWarning: Resolving the schema of a LazyFrame is a potentially expensive operation. Use `LazyFrame.collect_schema()` to get the schema without this warning.
#   schema = df.schema.copy()
# Schema([('query_name', String),
#         ('query_md5', String),
#         ('match_name', String),
#         ('match_md5', String),
#         ('containment', Float64),
#         ('max_containment', Float64),
#         ('jaccard', Float64),
#         ('intersect_hashes', Float64),
#         ('prob_overlap', Float64),
#         ('prob_overlap_adjusted', Float64),
#         ('containment_adjusted', Float64),
#         ('containment_adjusted_log10', Float64),
#         ('tf_idf_score', Float64)])

# %% [markdown]
# ## Read metadata

# %% [markdown]
# ### Read Query Metadata

# %%
query_metadata = pl.scan_parquet(
    "s3://seanome-kmerseek/scope-benchmark/reference_files/scop.e.2.08.query_metadata.pq",
    low_memory=True,
)
query_metadata
# Out:
# /home/ec2-user/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/IPython/core/formatters.py:347: UserWarning: '(default_)region' not set; polars will try to get it from bucket
#
# Set the region manually to silence this warning.
#   return method()
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="672pt" height="46pt"
#  viewBox="0.00 0.00 672.00 46.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 42)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-42 668,-42 668,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="664,-38 0,-38 0,0 664,0 664,-38"/>
# <text text-anchor="middle" x="332" y="-22.8" font-family="Times-Roman" font-size="14.00">Parquet SCAN [s3://seanome&#45;kmerseek/scope&#45;benchmark/reference_files/scop.e.2.08.query_metadata.pq]</text>
# <text text-anchor="middle" x="332" y="-7.8" font-family="Times-Roman" font-size="14.00">π */10;</text>
# </g>
# </g>
# </svg>

# %%
# print(query_metadata.head().collect().write_csv())

# %% [markdown]
# ### Read match metadata

# %%
match_metadata = pl.scan_parquet(
    "s3://seanome-kmerseek/scope-benchmark/reference_files/scop.e.2.08.match_metadata.pq",
    low_memory=True,
)
match_metadata
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="675pt" height="46pt"
#  viewBox="0.00 0.00 675.00 46.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 42)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-42 671,-42 671,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="667,-38 0,-38 0,0 667,0 667,-38"/>
# <text text-anchor="middle" x="333.5" y="-22.8" font-family="Times-Roman" font-size="14.00">Parquet SCAN [s3://seanome&#45;kmerseek/scope&#45;benchmark/reference_files/scop.e.2.08.match_metadata.pq]</text>
# <text text-anchor="middle" x="333.5" y="-7.8" font-family="Times-Roman" font-size="14.00">π */6;</text>
# </g>
# </g>
# </svg>

# %%
print(match_metadata.head().collect().write_csv())
# Out:
# match_name,match_family,match_superfamily,match_fold,match_class,match_scop_id
# d1x3ka_ a.1.1.0 (A:) automated matches {Tokunagayusurika akamusi [TaxId: 28383]},a.1.1.0,a.1.1,a.1,a,d1x3ka_
# d1x46a_ a.1.1.0 (A:) automated matches {Tokunagayusurika akamusi [TaxId: 28383]},a.1.1.0,a.1.1,a.1,a,d1x46a_
# d2bk9a_ a.1.1.0 (A:) automated matches {Fruit fly (Drosophila melanogaster) [TaxId: 7227]},a.1.1.0,a.1.1,a.1,a,d2bk9a_
# d2c0ka_ a.1.1.0 (A:) automated matches {Gasterophilus intestinalis [TaxId: 84525]},a.1.1.0,a.1.1,a.1,a,d2c0ka_
# d2ig3a_ a.1.1.0 (A:) automated matches {Campylobacter jejuni [TaxId: 197]},a.1.1.0,a.1.1,a.1,a,d2ig3a_

# %%
# Skip ksizes 5 and 6 for now because those files are enormous, 2.3 GiB for k=5 and 175 MiB for k=6
# # -> Figure out how to use polars later
# ksizes = range(7, 21)
# moltype = "protein"

moltype_info = {
    # "protein": dict(
    #     ksizes=range(5, 21),
    #     pipeline_outdir="s3://seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-08__protein_k5-20",
    #     analysis_outdir="s3://seanome-kmerseek/scope-benchmark/analysis-outputs/protein",
    # ),
    # "dayhoff": dict(
    #     ksizes=range(5, 21),
    #     pipeline_outdir="s3://seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__dayhoff_k5-20",
    #     analysis_outdir="s3://seanome-kmerseek/scope-benchmark/analysis-outputs/dayhoff",
    # ),
    "hp": dict(
        ksizes=range(10, 20),
        # pipeline_outdir="s3://seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__hp_k20-60",
        pipeline_outdir="/home/ec2-user/data/seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__hp_k20-60",
        # analysis_outdir="s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp",
        analysis_outdir="/home/ec2-user/data/seanome-kmerseek/scope-benchmark/analysis-outputs/hp",
    ),
}

for moltype, info in moltype_info.items():
    ksizes = info["ksizes"]
    analysis_outdir = info["analysis_outdir"]
    pipeline_outdir = info["pipeline_outdir"]
    for ksize in ksizes:
        # try:
        parser = MultisearchParser(
            query_metadata=query_metadata,
            match_metadata=match_metadata,
            pipeline_outdir=pipeline_outdir,
            moltype=moltype,
            ksize=ksize,
            analysis_outdir=analysis_outdir,
            verbose=True,
            input_filetype="pq",
            chunk_size=10000,
            # schema=schema,
            # chunk_size=100000, # Default
        )
        lf = parser.process_multisearch_scop_results()
    #     break
    # break
    # lf.head().collect()
    # except FileNotFoundError:
    #     pass

    # break
lf
# Out:
# 2024-10-31 23:28 - DEBUG -
# --- moltype: hp, ksize: 10 --
#
# --- moltype: hp, ksize: 10 --
#
# --- moltype: hp, ksize: 10 --
# 2024-10-31 23:28 - DEBUG - Processing /home/ec2-user/data/seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__hp_k20-60/sourmash/multisearch/astral-scopedom-seqres-gd-sel-gs-bib-40-2.08.part_001.fa--in--astral-scopedom-seqres-gd-sel-gs-bib-40-2.08.part_001.fa.hp.10.multisearch.pq ...
# Processing /home/ec2-user/data/seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__hp_k20-60/sourmash/multisearch/astral-scopedom-seqres-gd-sel-gs-bib-40-2.08.part_001.fa--in--astral-scopedom-seqres-gd-sel-gs-bib-40-2.08.part_001.fa.hp.10.multisearch.pq ...
# Processing /home/ec2-user/data/seanome-kmerseek/scope-benchmark/pipeline-outputs/2024-10-09__hp_k20-60/sourmash/multisearch/astral-scopedom-seqres-gd-sel-gs-bib-40-2.08.part_001.fa--in--astral-scopedom-seqres-gd-sel-gs-bib-40-2.08.part_001.fa.hp.10.multisearch.pq ...
# 2024-10-31 23:28 - DEBUG - Processing chunk 1
# Processing chunk 1
# Processing chunk 1
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 2
# Processing chunk 2
# Processing chunk 2
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 3
# Processing chunk 3
# Processing chunk 3
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 4
# Processing chunk 4
# Processing chunk 4
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 5
# Processing chunk 5
# Processing chunk 5
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 6
# Processing chunk 6
# Processing chunk 6
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 7
# Processing chunk 7
# Processing chunk 7
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 8
# Processing chunk 8
# Processing chunk 8
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 9
# Processing chunk 9
# Processing chunk 9
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 10
# Processing chunk 10
# Processing chunk 10
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 11
# Processing chunk 11
# Processing chunk 11
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 12
# Processing chunk 12
# Processing chunk 12
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 13
# Processing chunk 13
# Processing chunk 13
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 14
# Processing chunk 14
# Processing chunk 14
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 15
# Processing chunk 15
# Processing chunk 15
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 16
# Processing chunk 16
# Processing chunk 16
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 17
# Processing chunk 17
# Processing chunk 17
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 18
# Processing chunk 18
# Processing chunk 18
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 19
# Processing chunk 19
# Processing chunk 19
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 20
# Processing chunk 20
# Processing chunk 20
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 21
# Processing chunk 21
# Processing chunk 21
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 22
# Processing chunk 22
# Processing chunk 22
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 23
# Processing chunk 23
# Processing chunk 23
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 24
# Processing chunk 24
# Processing chunk 24
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 25
# Processing chunk 25
# Processing chunk 25
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 26
# Processing chunk 26
# Processing chunk 26
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 27
# Processing chunk 27
# Processing chunk 27
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 28
# Processing chunk 28
# Processing chunk 28
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 29
# Processing chunk 29
# Processing chunk 29
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 30
# Processing chunk 30
# Processing chunk 30
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 31
# Processing chunk 31
# Processing chunk 31
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 32
# Processing chunk 32
# Processing chunk 32
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 33
# Processing chunk 33
# Processing chunk 33
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 34
# Processing chunk 34
# Processing chunk 34
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 35
# Processing chunk 35
# Processing chunk 35
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 36
# Processing chunk 36
# Processing chunk 36
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 37
# Processing chunk 37
# Processing chunk 37
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 38
# Processing chunk 38
# Processing chunk 38
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 39
# Processing chunk 39
# Processing chunk 39
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 40
# Processing chunk 40
# Processing chunk 40
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 41
# Processing chunk 41
# Processing chunk 41
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 42
# Processing chunk 42
# Processing chunk 42
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 43
# Processing chunk 43
# Processing chunk 43
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 44
# Processing chunk 44
# Processing chunk 44
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 45
# Processing chunk 45
# Processing chunk 45
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 46
# Processing chunk 46
# Processing chunk 46
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 47
# Processing chunk 47
# Processing chunk 47
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 48
# Processing chunk 48
# Processing chunk 48
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 49
# Processing chunk 49
# Processing chunk 49
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 50
# Processing chunk 50
# Processing chunk 50
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 51
# Processing chunk 51
# Processing chunk 51
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 52
# Processing chunk 52
# Processing chunk 52
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 53
# Processing chunk 53
# Processing chunk 53
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 54
# Processing chunk 54
# Processing chunk 54
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 55
# Processing chunk 55
# Processing chunk 55
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 56
# Processing chunk 56
# Processing chunk 56
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 57
# Processing chunk 57
# Processing chunk 57
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 58
# Processing chunk 58
# Processing chunk 58
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 59
# Processing chunk 59
# Processing chunk 59
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 60
# Processing chunk 60
# Processing chunk 60
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 61
# Processing chunk 61
# Processing chunk 61
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 62
# Processing chunk 62
# Processing chunk 62
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 63
# Processing chunk 63
# Processing chunk 63
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 64
# Processing chunk 64
# Processing chunk 64
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 65
# Processing chunk 65
# Processing chunk 65
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 66
# Processing chunk 66
# Processing chunk 66
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 67
# Processing chunk 67
# Processing chunk 67
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 68
# Processing chunk 68
# Processing chunk 68
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 69
# Processing chunk 69
# Processing chunk 69
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 70
# Processing chunk 70
# Processing chunk 70
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 71
# Processing chunk 71
# Processing chunk 71
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 72
# Processing chunk 72
# Processing chunk 72
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 73
# Processing chunk 73
# Processing chunk 73
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 74
# Processing chunk 74
# Processing chunk 74
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 75
# Processing chunk 75
# Processing chunk 75
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 76
# Processing chunk 76
# Processing chunk 76
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 77
# Processing chunk 77
# Processing chunk 77
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 78
# Processing chunk 78
# Processing chunk 78
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# ...
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 146
# Processing chunk 146
# Processing chunk 146
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 147
# Processing chunk 147
# Processing chunk 147
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 148
# Processing chunk 148
# Processing chunk 148
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 149
# Processing chunk 149
# Processing chunk 149
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 150
# Processing chunk 150
# Processing chunk 150
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 151
# Processing chunk 151
# Processing chunk 151
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 152
# Processing chunk 152
# Processing chunk 152
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 153
# Processing chunk 153
# Processing chunk 153
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 154
# Processing chunk 154
# Processing chunk 154
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 155
# Processing chunk 155
# Processing chunk 155
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 156
# Processing chunk 156
# Processing chunk 156
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 157
# Processing chunk 157
# Processing chunk 157
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 158
# Processing chunk 158
# Processing chunk 158
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 159
# Processing chunk 159
# Processing chunk 159
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 160
# Processing chunk 160
# Processing chunk 160
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 161
# Processing chunk 161
# Processing chunk 161
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 162
# Processing chunk 162
# Processing chunk 162
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 163
# Processing chunk 163
# Processing chunk 163
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 164
# Processing chunk 164
# Processing chunk 164
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 165
# Processing chunk 165
# Processing chunk 165
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 166
# Processing chunk 166
# Processing chunk 166
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 167
# Processing chunk 167
# Processing chunk 167
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 168
# Processing chunk 168
# Processing chunk 168
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 169
# Processing chunk 169
# Processing chunk 169
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 170
# Processing chunk 170
# Processing chunk 170
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# Adding ksize, moltype and log10 versions of score value columns
# 2024-10-31 23:28 - DEBUG - Processing chunk 171
# Processing chunk 171
# Processing chunk 171
# 2024-10-31 23:28 - INFO - Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# Removing self-matches and spurious single-hash matches
# 2024-10-31 23:28 - INFO - Joining chunk with metadata
# Joining chunk with metadata
# Joining chunk with metadata
# 2024-10-31 23:28 - INFO - Adding ksize, moltype and log10 versions of score value columns

# %%
# %debug
