# %% [markdown]
# # Imports and setup

# %% [markdown]
# ### Auto-re-import python modules, useful for editing local fils

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
import itertools
import warnings
from collections import Counter

import matplotlib as mpl
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
from sklearn.metrics import (
    DetCurveDisplay,
    PrecisionRecallDisplay,
    RocCurveDisplay,
    accuracy_score,
    average_precision_score,
    balanced_accuracy_score,
    classification_report,
    det_curve,
    f1_score,
    precision_recall_curve,
    precision_recall_fscore_support,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
    top_k_accuracy_score,
)

pd.options.display.max_columns = 100

mpl.rcParams["figure.max_open_warning"] = 0

# %%
# assert pl.__version__ == "1.9.0"

# %% [markdown]
# # Read in data

# %%
analysis_outdir = (
    "s3://seanome-kmerseek/scope-benchmark/analysis-outputs/2024-10-09__protein_k5-20"
)

# %% [markdown]
# ### ~Explore with protein, k=7~

# %%
# Skip ksizes 5 and 6 for now because those files are enormous, 2.3 GiB for k=5 and 175 MiB for k=6
# -> Figure out how to use polars later
ksizes = range(7, 21)

# %%
ksize = 7
# pq = make_multisearch_pq(ksize, analysis_outdir, "protein")
# multisearch = pd.read_parquet(pq)
# print(multisearch.shape)
# multisearch.head()

# %%
lineage_cols = ["family", "superfamily", "fold", "class"]

# %% [markdown]
# ## Explore with hp, ksize=10

# %%
! aws s3 ls s3://seanome-kmerseek/scope-benchmark/analysis-outputs/hp/00_cleaned_multisearch_results/
# Out:
# 2024-11-01 22:15:03 38055296032 scope40.multisearch.hp.k10.filtered.pq
# 2024-11-01 22:15:03 34811214779 scope40.multisearch.hp.k11.filtered.pq
# 2024-11-01 22:15:03 29073335058 scope40.multisearch.hp.k12.filtered.pq
# 2024-11-01 22:15:03 21601970241 scope40.multisearch.hp.k13.filtered.pq
# 2024-11-01 22:15:03 14128957825 scope40.multisearch.hp.k14.filtered.pq
# 2024-11-01 22:24:08 8236169074 scope40.multisearch.hp.k15.filtered.pq
# 2024-11-01 22:28:58 4397537474 scope40.multisearch.hp.k16.filtered.pq
# 2024-11-01 22:29:32 2232431654 scope40.multisearch.hp.k17.filtered.pq
# 2024-11-01 22:31:04 1108792407 scope40.multisearch.hp.k18.filtered.pq
# 2024-11-01 22:31:48  547138735 scope40.multisearch.hp.k19.filtered.pq
# 2024-11-01 22:21:30  148970746 scope40.multisearch.hp.k20.filtered.pq
# 2024-11-01 22:21:32  266528288 scope40.multisearch.hp.k20.pq
# 2024-11-01 22:21:37   73471226 scope40.multisearch.hp.k21.filtered.pq
# 2024-11-01 22:21:38  131280255 scope40.multisearch.hp.k21.pq
# 2024-11-01 22:21:33   37211776 scope40.multisearch.hp.k22.filtered.pq
# 2024-11-01 22:21:31   67829683 scope40.multisearch.hp.k22.pq
# 2024-11-01 22:21:34   19593596 scope40.multisearch.hp.k23.filtered.pq
# 2024-11-01 22:21:34   35583004 scope40.multisearch.hp.k23.pq
# 2024-11-01 22:21:34   10651873 scope40.multisearch.hp.k24.filtered.pq
# 2024-11-01 22:21:37   19449323 scope40.multisearch.hp.k24.pq
# 2024-11-01 22:21:34    5893593 scope40.multisearch.hp.k25.filtered.pq
# 2024-11-01 22:21:39   11495754 scope40.multisearch.hp.k25.pq
# 2024-11-01 22:21:35    3262063 scope40.multisearch.hp.k26.filtered.pq
# 2024-11-01 22:21:35    7462970 scope40.multisearch.hp.k26.pq
# 2024-11-01 22:21:35    2171794 scope40.multisearch.hp.k27.filtered.pq
# 2024-11-01 22:21:35    5295384 scope40.multisearch.hp.k27.pq
# 2024-11-01 22:21:35    1385066 scope40.multisearch.hp.k28.filtered.pq
# 2024-11-01 22:21:35    4278930 scope40.multisearch.hp.k28.pq
# 2024-11-01 22:21:35     849243 scope40.multisearch.hp.k29.filtered.pq
# 2024-11-01 22:21:35    3719805 scope40.multisearch.hp.k29.pq
# 2024-11-01 22:21:35     536882 scope40.multisearch.hp.k30.filtered.pq
# 2024-11-01 22:21:35    3429020 scope40.multisearch.hp.k30.pq
# 2024-11-01 22:21:35     357074 scope40.multisearch.hp.k31.filtered.pq
# 2024-11-01 22:21:35    3278914 scope40.multisearch.hp.k31.pq
# 2024-11-01 22:21:35     253824 scope40.multisearch.hp.k32.filtered.pq
# 2024-11-01 22:21:35    3188104 scope40.multisearch.hp.k32.pq
# 2024-11-01 22:21:35     190600 scope40.multisearch.hp.k33.filtered.pq
# 2024-11-01 22:21:35    3141211 scope40.multisearch.hp.k33.pq
# 2024-11-01 22:21:35     157412 scope40.multisearch.hp.k34.filtered.pq
# 2024-11-01 22:21:35    3104661 scope40.multisearch.hp.k34.pq
# 2024-11-01 22:21:35     132224 scope40.multisearch.hp.k35.filtered.pq
# 2024-11-01 22:21:35    3079694 scope40.multisearch.hp.k35.pq
# 2024-11-01 22:21:35     119362 scope40.multisearch.hp.k36.filtered.pq
# 2024-11-01 22:21:35    3062163 scope40.multisearch.hp.k36.pq
# 2024-11-01 22:21:35     110960 scope40.multisearch.hp.k37.filtered.pq
# 2024-11-01 22:21:35    3051327 scope40.multisearch.hp.k37.pq
# 2024-11-01 22:21:35     106130 scope40.multisearch.hp.k38.filtered.pq
# 2024-11-01 22:21:35    3036500 scope40.multisearch.hp.k38.pq
# 2024-11-01 22:21:35     102427 scope40.multisearch.hp.k39.filtered.pq
# 2024-11-01 22:21:36    3028554 scope40.multisearch.hp.k39.pq
# 2024-11-01 22:21:36      98579 scope40.multisearch.hp.k40.filtered.pq
# 2024-11-01 22:21:36    3024481 scope40.multisearch.hp.k40.pq
# 2024-11-01 22:21:36      97008 scope40.multisearch.hp.k41.filtered.pq
# 2024-11-01 22:21:36    3019533 scope40.multisearch.hp.k41.pq
# 2024-11-01 22:21:36      94432 scope40.multisearch.hp.k42.filtered.pq
# 2024-11-01 22:21:36    3016273 scope40.multisearch.hp.k42.pq
# 2024-11-01 22:21:36      93753 scope40.multisearch.hp.k43.filtered.pq
# 2024-11-01 22:21:36    3007589 scope40.multisearch.hp.k43.pq
# 2024-11-01 22:21:36      92730 scope40.multisearch.hp.k44.filtered.pq
# 2024-11-01 22:21:36    3006777 scope40.multisearch.hp.k44.pq
# 2024-11-01 22:21:36      91991 scope40.multisearch.hp.k45.filtered.pq
# 2024-11-01 22:21:36    3003383 scope40.multisearch.hp.k45.pq
# 2024-11-01 22:21:36      91863 scope40.multisearch.hp.k46.filtered.pq
# 2024-11-01 22:21:36    2998628 scope40.multisearch.hp.k46.pq
# 2024-11-01 22:21:36      91677 scope40.multisearch.hp.k47.filtered.pq
# 2024-11-01 22:21:36    2994044 scope40.multisearch.hp.k47.pq
# 2024-11-01 22:21:36      91538 scope40.multisearch.hp.k48.filtered.pq
# 2024-11-01 22:21:36    2989024 scope40.multisearch.hp.k48.pq
# 2024-11-01 22:21:36      91398 scope40.multisearch.hp.k49.filtered.pq
# 2024-11-01 22:21:36    2987077 scope40.multisearch.hp.k49.pq
# 2024-11-01 22:21:36      91258 scope40.multisearch.hp.k50.filtered.pq
# 2024-11-01 22:21:36    2975003 scope40.multisearch.hp.k50.pq
# 2024-11-01 22:21:36      90441 scope40.multisearch.hp.k51.filtered.pq
# 2024-11-01 22:21:36    2969836 scope40.multisearch.hp.k51.pq
# 2024-11-01 22:21:36      89944 scope40.multisearch.hp.k52.filtered.pq
# 2024-11-01 22:21:36    2964309 scope40.multisearch.hp.k52.pq
# 2024-11-01 22:21:36      89043 scope40.multisearch.hp.k53.filtered.pq
# 2024-11-01 22:21:36    2956308 scope40.multisearch.hp.k53.pq
# 2024-11-01 22:21:36      88923 scope40.multisearch.hp.k54.filtered.pq
# 2024-11-01 22:21:36    2955151 scope40.multisearch.hp.k54.pq
# 2024-11-01 22:21:37      88798 scope40.multisearch.hp.k55.filtered.pq
# 2024-11-01 22:21:37    2950248 scope40.multisearch.hp.k55.pq
# 2024-11-01 22:21:37      88597 scope40.multisearch.hp.k56.filtered.pq
# 2024-11-01 22:21:37    2945675 scope40.multisearch.hp.k56.pq
# 2024-11-01 22:21:37      88475 scope40.multisearch.hp.k57.filtered.pq
# 2024-11-01 22:21:37    2936996 scope40.multisearch.hp.k57.pq
# 2024-11-01 22:21:37      88261 scope40.multisearch.hp.k58.filtered.pq
# 2024-11-01 22:21:37    2928662 scope40.multisearch.hp.k58.pq
# 2024-11-01 22:21:37      88039 scope40.multisearch.hp.k59.filtered.pq
# 2024-11-01 22:21:37    2920513 scope40.multisearch.hp.k59.pq
# 2024-11-01 22:21:37      87823 scope40.multisearch.hp.k60.filtered.pq
# 2024-11-01 22:21:37    2915683 scope40.multisearch.hp.k60.pq
# 2024-11-01 22:21:39   10651873 scope40.multisearch.protein.k24.filtered.pq
# 2024-11-01 22:21:40   19449323 scope40.multisearch.protein.k24.pq
# 2024-11-01 22:21:38    5893593 scope40.multisearch.protein.k25.filtered.pq
# 2024-11-01 22:21:39   11495754 scope40.multisearch.protein.k25.pq
# 2024-11-01 22:21:39    3262063 scope40.multisearch.protein.k26.filtered.pq
# 2024-11-01 22:21:39    7462970 scope40.multisearch.protein.k26.pq
# 2024-11-01 22:21:39    2171794 scope40.multisearch.protein.k27.filtered.pq
# 2024-11-01 22:21:39    5295384 scope40.multisearch.protein.k27.pq

# %%
! aws s3 ls s3://seanome-kmerseek/scope-benchmark/analysis-outputs/
# Out:
#                            PRE 2024-10-08__protein_k5-20/
#                            PRE 2024-10-09__hp_k20-60/
#                            PRE 2024-10-09__protein_k5-20/
#                            PRE 2024-10-11__subsample_1000_queries/
#                            PRE hp/

# %%
# ! aws s3 ls s3://seanome-kmerseek/scope-benchmark/analysis-outputs/2024-10-09__protein_k5-20/00_cleaned_multisearch_results/

# %%
# def make_multisearch_pq(
#     ksize,
#     outdir,
#     moltype,
# ):
#     basename = f"scope40.multisearch.{moltype}.k{ksize}.pq"
#     pq = f"{outdir}/00_cleaned_multisearch_results/{basename}"
#     return pq


pq = "s3://seanome-kmerseek/scope-benchmark/analysis-outputs/2024-10-09__hp_k20-60/00_cleaned_multisearch_results/scope40.multisearch.hp.k10.filtered.pq"
multisearch = pl.read_parquet(pq)
multisearch["prob_overlap_adjusted_inverse"] = 1 / multisearch["prob_overlap_adjusted"]
print(multisearch.shape)
multisearch.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       1 # def make_multisearch_pq(
#       2 #     ksize,
#       3 #     outdir,
#    (...)
#       7 #     pq = f"{outdir}/00_cleaned_multisearch_results/{basename}"
#       8 #     return pq
#      11 pq = "s3://seanome-kmerseek/scope-benchmark/analysis-outputs/2024-10-09__hp_k20-60/00_cleaned_multisearch_results/scope40.multisearch.hp.k10.filtered.pq"
# ---> 12 multisearch = pd.read_parquet(pq)
#      13 multisearch["prob_overlap_adjusted_inverse"] = 1 / multisearch["prob_overlap_adjusted"]
#      14 print(multisearch.shape)
#
# NameError: name 'pd' is not defined

# %%
# sns.jointplot(multisearch, x="containment", y="containment_adjusted_log10")

# %%
same_lineage_cols = [f"same_{x}" for x in lineage_cols]

# %%
# for same_lineage in same_lineage_cols:
#     sns.jointplot(
#         multisearch, x="containment", y="containment_adjusted_log10", hue=same_lineage
#     )

# %% [markdown]
# ## I want to compare all the metrics for these different classes

# %%
sourmash_score_cols = (
    "containment",
    "tf_idf_score",
    "containment_adjusted_log10",
    "prob_overlap_adjusted",
)

# %%
multisearch.shape
# Out:
# (1761706, 32)

# %%
multisearch_melt_scop_levels = multisearch.melt(
    id_vars=["query_name", "match_name"],
    value_vars=same_lineage_cols,
    var_name="scop_level",
    value_name="is_same",
)
multisearch_melt_scop_levels["scop_level"] = (
    multisearch_melt_scop_levels["scop_level"].str.split("_").str[-1]
)
print(multisearch_melt_scop_levels.shape)
multisearch_melt_scop_levels.head()
# Out:
# (7046824, 4)
#                                           query_name  \
# 0  d2fcwa1 a.13.1.1 (A:216-320) alpha-2-Macroglob...
# 1  d6d5xa_ a.25.2.0 (A:) automated matches {Human...
# 2  d4dlla2 a.100.1.0 (A:191-316) automated matche...
# 3  d1n4ka1 a.118.22.1 (A:436-602) IP3 receptor ty...
# 4  d6s7ja_ a.127.1.0 (A:) automated matches {Trep...
#
#                                           match_name scop_level  is_same
# 0  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...     family    False
# 1  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...     family    False
# 2  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...     family    False
# 3  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...     family    False
# 4  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...     family    False

# %%
value_cols = multisearch.columns[multisearch.dtypes == float]

multisearch_melt_sourmash_score = multisearch.melt(
    id_vars=["query_name", "match_name"],
    value_vars=value_cols,
    var_name="sourmash_score",
    value_name="score_value",
)
print(multisearch_melt_sourmash_score.shape)
multisearch_melt_sourmash_score.head()
# Out:
# (17617060, 4)
#                                           query_name  \
# 0  d2fcwa1 a.13.1.1 (A:216-320) alpha-2-Macroglob...
# 1  d6d5xa_ a.25.2.0 (A:) automated matches {Human...
# 2  d4dlla2 a.100.1.0 (A:191-316) automated matche...
# 3  d1n4ka1 a.118.22.1 (A:436-602) IP3 receptor ty...
# 4  d6s7ja_ a.127.1.0 (A:) automated matches {Trep...
#
#                                           match_name sourmash_score  \
# 0  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
# 1  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
# 2  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
# 3  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
# 4  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
#
#    score_value
# 0     0.034884
# 1     0.028169
# 2     0.018692
# 3     0.027027
# 4     0.004184

# %%
multisearch_melt_combined = multisearch_melt_sourmash_score.merge(
    multisearch_melt_scop_levels, on=["query_name", "match_name"]
)
print(multisearch_melt_combined.shape)
multisearch_melt_combined.head()
# Out:
# (70468240, 6)
#                                           query_name  \
# 0  d2fcwa1 a.13.1.1 (A:216-320) alpha-2-Macroglob...
# 1  d2fcwa1 a.13.1.1 (A:216-320) alpha-2-Macroglob...
# 2  d2fcwa1 a.13.1.1 (A:216-320) alpha-2-Macroglob...
# 3  d2fcwa1 a.13.1.1 (A:216-320) alpha-2-Macroglob...
# 4  d6d5xa_ a.25.2.0 (A:) automated matches {Human...
#
#                                           match_name sourmash_score  \
# 0  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
# 1  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
# 2  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
# 3  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
# 4  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...    containment
#
#    score_value   scop_level  is_same
# 0     0.034884       family    False
# 1     0.034884  superfamily    False
# 2     0.034884         fold    False
# 3     0.034884        class     True
# 4     0.028169       family    False

# %%
# sns.catplot(x="sourmash_score", y="value", hue="same_family", data=multisearch_melted)

# %%
sns.catplot(
    x="sourmash_score",
    y="score_value",
    hue="is_same",
    data=multisearch_melt_combined.query("scop_level == 'family'"),
    kind="bar",
)

# %%
for lineage_col in lineage_cols:
    query = f"query_{lineage_col}"
    match = f"match_{lineage_col}"

    multisearch[lineage_col] = multisearch[query] == multisearch[match]

# Ignore self matches
print(f"Before removing self-matches: {multisearch.shape}")
multisearch_no_self = multisearch.query("query_name != match_name")
print(f"After  removing self-matches: {multisearch_no_self.shape}")
# Out:
# Before removing self-matches: (1761706, 36)
# After  removing self-matches: (1761706, 36)

# %%
# Ignore self matches
print(f"Before removing spurious matches: {multisearch_no_self.shape}")
multisearch_no_self_no_spurious = multisearch_no_self.query("intersect_hashes > 1")
print(f"After  removing spurious matches {multisearch_no_self_no_spurious.shape}")
# Out:
# Before removing spurious matches: (221276, 35)
# After  removing spurious matches (111138, 35)

# %%
multisearch_no_self_no_spurious.dtypes
# Out:
# query_name                      object
# query_md5                       object
# match_name                      object
# match_md5                       object
# containment                    float64
# max_containment                float64
# jaccard                        float64
# intersect_hashes               float64
# prob_overlap                   float64
# prob_overlap_adjusted          float64
# containment_adjusted           float64
# containment_adjusted_log10     float64
# tf_idf_score                   float64
# query_scop_id                   object
# query_scop_lineage              object
# query_scop_lineage_fixed        object
# query_family                  category
# query_superfamily             category
# query_fold                    category
# query_class                   category
# match_scop_id                   object
# match_scop_lineage              object
# match_scop_lineage_fixed        object
# match_family                  category
# match_superfamily             category
# match_fold                    category
# match_class                   category
# same_family                       bool
# same_superfamily                  bool
# same_fold                         bool
# same_class                        bool
# family                            bool
# superfamily                       bool
# fold                              bool
# class                             bool
# dtype: object

# %% [markdown]
# ### Create a multisearch table where self-matches and spurious matches (intersect hashes =1) are zeroed out

# %%
multisearch_zero_self_spurious = multisearch.copy()


self_matches = multisearch_zero_self_spurious.query("query_md5 == match_md5").index
spurious_matches = multisearch_zero_self_spurious.query("intersect_hashes == 1").index

multisearch_zero_self_spurious.loc[self_matches, sourmash_score_cols] = 0
# multisearch_zero_self_spurious.loc[spurious_matches, sourmash_score_cols] = 0

# %% [markdown]
# ### Make query metadata

# %%
lineage_cols
# Out:
# ['family', 'superfamily', 'fold', 'class']

# %%
query_scop_cols = [f"query_{x}" for x in lineage_cols]
match_scop_cols = [f"match_{x}" for x in lineage_cols]

same_scop_cols = [f"same_{x}" for x in lineage_cols]

# groupby = [, query_scop_cols]

# %%
query_metadata = pd.DataFrame(
    multisearch[query_scop_cols].values,
    index=multisearch["query_scop_id"].values,
    columns=query_scop_cols,
)
query_metadata = query_metadata.sort_index()
print(query_metadata.shape)
query_metadata = query_metadata.loc[~query_metadata.index.duplicated()]
print(query_metadata.shape)
query_metadata.head()
# Out:
# (236445, 4)
# (15169, 4)
#         query_family query_superfamily query_fold query_class
# d12asa_    d.104.1.1           d.104.1      d.104           d
# d16vpa_    d.180.1.1           d.180.1      d.180           d
# d1914a1     d.49.1.1            d.49.1       d.49           d
# d1914a2     d.49.1.1            d.49.1       d.49           d
# d1a04a1      a.4.6.2             a.4.6        a.4           a

# %% [markdown]
# ### Compute pivot table to get `y_pred` for each class

# %%
query_vs_match_lineage_sourmash_score = multisearch_zero_self_spurious.pivot_table(
    index="query_scop_id",
    columns="match_class",
    values="containment_adjusted_log10",
    fill_value=0,
    aggfunc="max",
    dropna=False,
    observed=False,
)
query_vs_match_lineage_sourmash_score
# Out:
# match_class           a         b         c         d         e         f    g
# query_scop_id
# d12asa_        1.333135  1.333135  1.333135  1.270083  0.000000  0.000000  0.0
# d16vpa_        1.175465  1.293564  1.293564  1.293564  0.000000  1.293564  0.0
# d1914a1        1.723463  0.000000  2.075646  2.075646  0.000000  0.000000  0.0
# d1914a2        1.946777  1.946777  1.946777  1.946777  0.000000  1.946777  0.0
# d1a04a1        0.000000  2.172556  2.172556  0.000000  2.172556  0.000000  0.0
# ...                 ...       ...       ...       ...       ...       ...  ...
# g2dbx.1        1.100841  1.100841  1.100841  1.100841  1.100841  1.100841  0.0
# g2vt1.1        0.000000  1.912918  1.912918  1.912918  0.000000  0.000000  0.0
# g3bzy.1        1.923914  0.000000  1.923914  0.000000  0.000000  0.000000  0.0
# g3n55.1        1.833737  1.833737  1.833737  1.833737  1.833737  0.000000  0.0
# g6rlx.1        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
#
# [15169 rows x 7 columns]

# %%
query_vs_match_lineage_sourmash_score
# Out:
# match_class           a         b         c         d         e         f    g
# query_scop_id
# d12asa_        1.333135  1.333135  1.333135  1.270083  0.000000  0.000000  0.0
# d16vpa_        1.175465  1.293564  1.293564  1.293564  0.000000  1.293564  0.0
# d1914a1        1.723463  0.000000  2.075646  2.075646  0.000000  0.000000  0.0
# d1914a2        1.946777  1.946777  1.946777  1.946777  0.000000  1.946777  0.0
# d1a04a1        0.000000  2.172556  2.172556  0.000000  2.172556  0.000000  0.0
# ...                 ...       ...       ...       ...       ...       ...  ...
# g2dbx.1        1.100841  1.100841  1.100841  1.100841  1.100841  1.100841  0.0
# g2vt1.1        0.000000  1.912918  1.912918  1.912918  0.000000  0.000000  0.0
# g3bzy.1        1.923914  0.000000  1.923914  0.000000  0.000000  0.000000  0.0
# g3n55.1        1.833737  1.833737  1.833737  1.833737  1.833737  0.000000  0.0
# g6rlx.1        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
#
# [15169 rows x 7 columns]

# %%
y_pred = query_vs_match_lineage_sourmash_score.idxmax(axis=1).sort_index()
y_pred
# Out:
# query_scop_id
# d12asa_    a
# d16vpa_    b
# d1914a1    c
# d1914a2    a
# d1a04a1    b
#           ..
# g2dbx.1    a
# g2vt1.1    b
# g3bzy.1    a
# g3n55.1    a
# g6rlx.1    a
# Length: 15169, dtype: category
# Categories (7, object): ['a' < 'b' < 'c' < 'd' < 'e' < 'f' < 'g']

# %%
# multisearch_no_self_no_spurious.pivot(index='query_name', values='query_class', columns='same_class')

# %%
y_true = pd.Series(
    index=multisearch_zero_self_spurious["query_scop_id"],
    data=multisearch_zero_self_spurious["query_class"].values,
)
y_true = y_true[~y_true.index.duplicated()].sort_index()
y_true
# Out:
# query_scop_id
# d12asa_    d
# d16vpa_    d
# d1914a1    d
# d1914a2    d
# d1a04a1    a
#           ..
# g2dbx.1    d
# g2vt1.1    d
# g3bzy.1    d
# g3n55.1    b
# g6rlx.1    g
# Length: 15169, dtype: category
# Categories (7, object): ['a' < 'b' < 'c' < 'd' < 'e' < 'f' < 'g']

# %%
query_vs_match_lineage_sourmash_score.head()
# Out:
# match_class           a         b         c         d         e         f    g
# query_scop_id
# d12asa_        1.333135  1.333135  1.333135  1.270083  0.000000  0.000000  0.0
# d16vpa_        1.175465  1.293564  1.293564  1.293564  0.000000  1.293564  0.0
# d1914a1        1.723463  0.000000  2.075646  2.075646  0.000000  0.000000  0.0
# d1914a2        1.946777  1.946777  1.946777  1.946777  0.000000  1.946777  0.0
# d1a04a1        0.000000  2.172556  2.172556  0.000000  2.172556  0.000000  0.0

# %%
# query_vs_match_lineage_sourmash_score.loc[y_true.index, y_true.values]

# %% [markdown]
# ### containment_adjusted_log10 for the true family (ignoring self matches and single hashes): I think I want to plot this for different ksizes

# %%
y_score = query_vs_match_lineage_sourmash_score.apply(y_true, axis=1).sort_index()
y_score
# Out:
# d12asa_    1.270083
# d16vpa_    1.293564
# d1914a1    2.075646
# d1914a2    1.946777
# d1a04a1    0.000000
#              ...
# g2dbx.1    1.100841
# g2vt1.1    1.912918
# g3bzy.1    0.000000
# g3n55.1    1.833737
# g6rlx.1    0.000000
# Length: 15169, dtype: float64

# %%
sns.displot(y_score)

# %%
precision_recall_fscore_support(y_true, y_pred)
# Out:
# (array([0.16974134, 0.27614321, 0.15502555, 0.23904382, 0.        ,
#         0.37037037, 0.44444444]),
#  array([0.65771558, 0.25490838, 0.06118333, 0.01642486, 0.        ,
#         0.03012048, 0.01114206]),
#  array([0.2698425 , 0.26510124, 0.08773903, 0.0307377 , 0.        ,
#         0.05571031, 0.02173913]),
#  array([2644, 3056, 4462, 3653,  304,  332,  718]))

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.17      0.66      0.27      2644
#            b       0.28      0.25      0.27      3056
#            c       0.16      0.06      0.09      4462
#            d       0.24      0.02      0.03      3653
#            e       0.00      0.00      0.00       304
#            f       0.37      0.03      0.06       332
#            g       0.44      0.01      0.02       718
#
#     accuracy                           0.19     15169
#    macro avg       0.24      0.15      0.10     15169
# weighted avg       0.22      0.19      0.14     15169

# %%
query_metadata.head()
# Out:
#         query_family query_superfamily query_fold query_class
# d12asa_    d.104.1.1           d.104.1      d.104           d
# d16vpa_    d.180.1.1           d.180.1      d.180           d
# d1914a1     d.49.1.1            d.49.1       d.49           d
# d1914a2     d.49.1.1            d.49.1       d.49           d
# d1a04a1      a.4.6.2             a.4.6        a.4           a

# %%
query_metadata.shape
# Out:
# (15169, 4)

# %%
y_true.head()
# Out:
# query_scop_id
# d12asa_    d
# d16vpa_    d
# d1914a1    d
# d1914a2    d
# d1a04a1    a
# dtype: category
# Categories (7, object): ['a' < 'b' < 'c' < 'd' < 'e' < 'f' < 'g']

# %%
y_true.shape
# Out:
# (15169,)

# %%
y_true.value_counts()
# Out:
# c    4462
# d    3653
# b    3056
# a    2644
# g     718
# f     332
# e     304
# Name: count, dtype: int64

# %%
y_true_bool = y_true == query_metadata["query_class"]
y_true_bool.value_counts()
# Out:
# True    15169
# Name: count, dtype: int64

# %%
# roc_auc_score(y_true_bool, y_score)

# %%
# RocCurveDisplay.from_predictions(y_true_bool, y_score)
# # d.plot()

# %%
# PrecisionRecallDisplay.from_predictions(y_true_bool, y_score)

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.17      0.66      0.27      2644
#            b       0.28      0.25      0.27      3056
#            c       0.16      0.06      0.09      4462
#            d       0.24      0.02      0.03      3653
#            e       0.00      0.00      0.00       304
#            f       0.37      0.03      0.06       332
#            g       0.44      0.01      0.02       718
#
#     accuracy                           0.19     15169
#    macro avg       0.24      0.15      0.10     15169
# weighted avg       0.22      0.19      0.14     15169

# %%
# precision_recall_curve(y_true, y_score)

# %%
multisearch_no_self_no_spurious.head()
# Out:
#                                            query_name  \
# 2   d2dita1 d.58.7.1 (A:8-106) HIV Tat-specific fa...
# 5   d1v5va2 d.250.1.1 (A:3-312) Glycine cleavage s...
# 6   d4cj9a_ a.298.1.1 (A:) BurrH {Burkholderia rhi...
# 7   d1g0da3 b.1.5.1 (A:584-684) Transglutaminase, ...
# 12  d2q7sa1 c.56.5.9 (A:10-289) N-formylglutamate ...
#
#                            query_md5  \
# 2   101ca324b2f0c3e29ad8f6e020339df3
# 5   f0227b386b4e8fe1535708eebe3b4bdc
# 6   fb393bfb4cab40b99294401548f50a00
# 7   77723abef0280214fd386a68077fde19
# 12  377b5699a6db7fae5c77d9492e6becc9
#
#                                            match_name  \
# 2   d4j42a_ a.25.3.0 (A:) automated matches {Bacil...
# 5   d4j42a_ a.25.3.0 (A:) automated matches {Bacil...
# 6   d3gcea_ b.33.1.0 (A:) automated matches {Nocar...
# 7   d3gcea_ b.33.1.0 (A:) automated matches {Nocar...
# 12  d3gcea_ b.33.1.0 (A:) automated matches {Nocar...
#
#                            match_md5  containment  max_containment   jaccard  \
# 2   2927928970a388981b12f1dba1be85b5     0.052632         0.070175  0.031008
# 5   2927928970a388981b12f1dba1be85b5     0.006969         0.035088  0.005848
# 6   6550c1f1f04d87d2f908386f437c61fb     0.003185         0.024691  0.002829
# 7   6550c1f1f04d87d2f908386f437c61fb     0.076923         0.076923  0.039216
# 12  6550c1f1f04d87d2f908386f437c61fb     0.011673         0.037037  0.008955
#
#     intersect_hashes  prob_overlap  prob_overlap_adjusted  \
# 2                4.0  2.652650e-12               0.000611
# 5                2.0  1.326325e-12               0.000306
# 6                2.0  4.144765e-12               0.000955
# 7                6.0  9.284273e-12               0.002139
# 12               3.0  5.636880e-12               0.001298
#
#     containment_adjusted  containment_adjusted_log10  tf_idf_score  \
# 2              86.137974                    1.935195      0.501526
# 5              22.810056                    1.358126      0.066404
# 6               3.335789                    0.523199      0.017954
# 7              35.969703                    1.555937      0.711697
# 12              8.990368                    0.953777      0.107007
#
#    query_scop_id query_scop_lineage query_scop_lineage_fixed query_family  \
# 2        d2dita1           d.58.7.1                 d.58.7.1     d.58.7.1
# 5        d1v5va2          d.250.1.1                d.250.1.1    d.250.1.1
# 6        d4cj9a_          a.298.1.1                a.298.1.1    a.298.1.1
# 7        d1g0da3            b.1.5.1                  b.1.5.1      b.1.5.1
# 12       d2q7sa1           c.56.5.9                 c.56.5.9     c.56.5.9
#
#    query_superfamily query_fold query_class match_scop_id match_scop_lineage  \
# 2             d.58.7       d.58           d       d4j42a_           a.25.3.0
# 5            d.250.1      d.250           d       d4j42a_           a.25.3.0
# 6            a.298.1      a.298           a       d3gcea_           b.33.1.0
# 7              b.1.5        b.1           b       d3gcea_           b.33.1.0
# 12            c.56.5       c.56           c       d3gcea_           b.33.1.0
#
#    match_scop_lineage_fixed match_family match_superfamily match_fold  \
# 2                  a.25.3.0     a.25.3.0            a.25.3       a.25
# 5                  a.25.3.0     a.25.3.0            a.25.3       a.25
# 6                  b.33.1.0     b.33.1.0            b.33.1       b.33
# 7                  b.33.1.0     b.33.1.0            b.33.1       b.33
# 12                 b.33.1.0     b.33.1.0            b.33.1       b.33
#
#    match_class  same_family  same_superfamily  same_fold  same_class  family  \
# 2            a        False             False      False       False   False
# 5            a        False             False      False       False   False
# 6            b        False             False      False       False   False
# 7            b        False             False      False        True   False
# 12           b        False             False      False       False   False
#
#     superfamily   fold  class
# 2         False  False  False
# 5         False  False  False
# 6         False  False  False
# 7         False  False   True
# 12        False  False  False

# %%
lineage_nunique = multisearch[
    ["query_family", "query_superfamily", "query_fold", "query_class"]
].value_counts()
lineage_nunique
# Out:
# query_family  query_superfamily  query_fold  query_class
# c.2.1.0       c.2.1              c.2         c              4627
# c.94.1.0      c.94.1             c.94        c              3611
# c.67.1.0      c.67.1             c.67        c              3525
# a.104.1.0     a.104.1            a.104       a              2239
# c.93.1.0      c.93.1             c.93        c              2219
#                                                             ...
# a.30.4.1      a.30.4             a.30        a                 1
# g.96.1.0      g.96.1             g.96        g                 1
# g.41.11.0     g.41.11            g.41        g                 1
# g.41.14.1     g.41.14            g.41        g                 1
# g.41.7.1      g.41.7             g.41        g                 1
# Name: count, Length: 4706, dtype: int64

# %%
multisearch_no_self[lineage_cols].sum()
# Out:
# family          2438
# superfamily     4946
# fold            6316
# class          66310
# dtype: int64

# %% [markdown]
# ## Explore what ther Foldseek paper did with "class"

# %%
lineage_col = "class"

# %%
lineage_class_value_counts = multisearch["query_class"].value_counts()
lineage_class_value_counts
# Out:
# query_class
# c    99676
# d    46977
# b    34598
# a    33223
# e    10354
# f     9432
# g     2185
# Name: count, dtype: int64

# %%
foldseek_scop_rocx = pd.read_csv(
    "https://raw.githubusercontent.com/steineggerlab/foldseek-analysis/1737c718bfafd9f6ac300fb6a0ddde6330166202/multidomain_benchmark/PLOTS/FIG2/foldseek.rocx",
    sep="\t",
    index_col=0,
)
foldseek_scop_rocx = foldseek_scop_rocx.sort_index()
foldseek_scop_rocx
# Out:
#               SCOP       FAM      SFAM      FOLD  FP  FAMCNT  SFAMCNT  FOLDCNT
# NAME
# d1a04a1    a.4.6.2  1.000000  0.125000  0.012422   1       5       13      335
# d1a04a2   c.23.1.1  1.000000  0.809524  0.038462   1      25       46      150
# d1a0ca_   c.1.15.3  1.000000  1.000000  0.129834   1       2       11      373
# d1a0ia1   b.40.4.6  0.833333  0.093750  0.000000   1       6      102      158
# d1a0ia2  d.142.2.1  1.000000  1.000000  0.000000   1       3        8       30
# ...            ...       ...       ...       ...  ..     ...      ...      ...
# d7fd1a_   d.58.1.2  0.666667  0.750000  0.003086   1       3       23      347
# d7odca1   b.49.2.3  1.000000  0.333333  0.000000   1       4        7       15
# d7odca2    c.1.6.1  1.000000  1.000000  0.049315   1       7        8      373
# d7reqa1   c.1.19.1  1.000000  1.000000  0.084239   1       2        5      373
# d7reqb1   c.1.19.1  1.000000  0.666667  0.035326   1       2        5      373
#
# [4229 rows x 8 columns]

# %%
cols = [
    "query_name",
    "match_name",
    "query_family",
    "match_family",
    "intersect_hashes",
    "containment",
    "prob_overlap_adjusted",
    "containment_adjusted_log10",
    "tf_idf_score",
]

multisearch.query('query_scop_id == "d1a04a1" and intersect_hashes > 1')[cols]
# Out:
#                                                query_name  \
# 4273    d1a04a1 a.4.6.2 (A:150-216) Nitrate/nitrite re...
# 87608   d1a04a1 a.4.6.2 (A:150-216) Nitrate/nitrite re...
# 90292   d1a04a1 a.4.6.2 (A:150-216) Nitrate/nitrite re...
# 98149   d1a04a1 a.4.6.2 (A:150-216) Nitrate/nitrite re...
# 220174  d1a04a1 a.4.6.2 (A:150-216) Nitrate/nitrite re...
#
#                                                match_name query_family  \
# 4273    d1a04a1 a.4.6.2 (A:150-216) Nitrate/nitrite re...      a.4.6.2
# 87608   d3ivma1 b.69.7.0 (A:7-417) automated matches {...      a.4.6.2
# 90292   d6tl8a_ c.10.2.0 (A:) automated matches {Mouse...      a.4.6.2
# 98149   d6tpla1 b.1.14.1 (A:555-657) Intimin {Escheric...      a.4.6.2
# 220174  d1d3ya_ e.12.1.1 (A:) DNA topoisomerase IV, al...      a.4.6.2
#
#        match_family  intersect_hashes  containment  prob_overlap_adjusted  \
# 4273        a.4.6.2              44.0     1.000000               0.003131
# 87608      b.69.7.0               2.0     0.045455               0.000306
# 90292      c.10.2.0               2.0     0.045455               0.000496
# 98149      b.1.14.1               2.0     0.045455               0.000306
# 220174     e.12.1.1               3.0     0.068182               0.000458
#
#         containment_adjusted_log10  tf_idf_score
# 4273                      2.504254      9.826551
# 87608                     2.172556      0.433136
# 90292                     1.961702      0.426598
# 98149                     2.172556      0.433136
# 220174                    2.172556      0.649704

# %%
cols = [
    "query_name",
    "match_name",
    "query_family",
    "match_family",
    "intersect_hashes",
    "containment",
    "prob_overlap_adjusted",
    "containment_adjusted_log10",
    "tf_idf_score",
]

multisearch.query('query_scop_id == "d1ty4a_" and intersect_hashes > 1')[cols]
# Out:
# Empty DataFrame
# Columns: [query_name, match_name, query_family, match_family, intersect_hashes, containment, prob_overlap_adjusted, containment_adjusted_log10, tf_idf_score]
# Index: []

# %%
bcl2_inhibitors_programmed_cell_death = "f.1.4.1"
multisearch.query(
    "query_family == @bcl2_inhibitors_programmed_cell_death and intersect_hashes > 1 and containment < 1"
)
# Out:
#                                                query_name  \
# 7574    d1ohua_ f.1.4.1 (A:) Apoptosis regulator ced-9...
# 13169   d7jgwa1 f.1.4.1 (A:1-196) Apoptosis regulator ...
# 22102   d1ddba_ f.1.4.1 (A:) Proapoptotic molecule Bid...
# 25945   d7jgwa1 f.1.4.1 (A:1-196) Apoptosis regulator ...
# 31578   d6udva_ f.1.4.1 (A:) EAT/MCL-1 (Myeloid cell l...
# 35162   d1ddba_ f.1.4.1 (A:) Proapoptotic molecule Bid...
# 46054   d1ddba_ f.1.4.1 (A:) Proapoptotic molecule Bid...
# 56696   d1ddba_ f.1.4.1 (A:) Proapoptotic molecule Bid...
# 57041   d1ohua_ f.1.4.1 (A:) Apoptosis regulator ced-9...
# 73382   d6udva_ f.1.4.1 (A:) EAT/MCL-1 (Myeloid cell l...
# 76424   d1ddba_ f.1.4.1 (A:) Proapoptotic molecule Bid...
# 88260   d1q59a1 f.1.4.1 (A:1-160) Early antigen protei...
# 93154   d3bl2a_ f.1.4.1 (A:) Bcl-2 homolog V-bcl-2 {Mu...
# 96292   d6udva_ f.1.4.1 (A:) EAT/MCL-1 (Myeloid cell l...
# 116948  d1ddba_ f.1.4.1 (A:) Proapoptotic molecule Bid...
# 117008  d3bl2a_ f.1.4.1 (A:) Bcl-2 homolog V-bcl-2 {Mu...
# 132316  d1ohua_ f.1.4.1 (A:) Apoptosis regulator ced-9...
# 132376  d1k3ka_ f.1.4.1 (A:) Bcl-2 homolog {Kaposi's s...
# 135715  d1ohua_ f.1.4.1 (A:) Apoptosis regulator ced-9...
# 144070  d6udva_ f.1.4.1 (A:) EAT/MCL-1 (Myeloid cell l...
# 151598  d1ohua_ f.1.4.1 (A:) Apoptosis regulator ced-9...
# 164534  d1k3ka_ f.1.4.1 (A:) Bcl-2 homolog {Kaposi's s...
# 166428  d6udva_ f.1.4.1 (A:) EAT/MCL-1 (Myeloid cell l...
# 167676  d7jgwa1 f.1.4.1 (A:1-196) Apoptosis regulator ...
# 174044  d1ohua_ f.1.4.1 (A:) Apoptosis regulator ced-9...
# 178451  d1q59a1 f.1.4.1 (A:1-160) Early antigen protei...
# 179006  d1ohua_ f.1.4.1 (A:) Apoptosis regulator ced-9...
# 182159  d7jgwa1 f.1.4.1 (A:1-196) Apoptosis regulator ...
# 183093  d1q59a1 f.1.4.1 (A:1-160) Early antigen protei...
# 183990  d3bl2a_ f.1.4.1 (A:) Bcl-2 homolog V-bcl-2 {Mu...
# 187893  d3bl2a_ f.1.4.1 (A:) Bcl-2 homolog V-bcl-2 {Mu...
# 189347  d3bl2a_ f.1.4.1 (A:) Bcl-2 homolog V-bcl-2 {Mu...
# 192135  d6udva_ f.1.4.1 (A:) EAT/MCL-1 (Myeloid cell l...
# 203077  d1k3ka_ f.1.4.1 (A:) Bcl-2 homolog {Kaposi's s...
# 213046  d1k3ka_ f.1.4.1 (A:) Bcl-2 homolog {Kaposi's s...
# 216787  d7jgwa1 f.1.4.1 (A:1-196) Apoptosis regulator ...
# 217319  d1ohua_ f.1.4.1 (A:) Apoptosis regulator ced-9...
# 225705  d3bl2a_ f.1.4.1 (A:) Bcl-2 homolog V-bcl-2 {Mu...
# 227484  d1ddba_ f.1.4.1 (A:) Proapoptotic molecule Bid...
# 235683  d1k3ka_ f.1.4.1 (A:) Bcl-2 homolog {Kaposi's s...
#
#                                query_md5  \
# 7574    a1140d1a054f3e3f9d084d6a290a54dd
# 13169   cd785d034250181e61281b8ab64798cc
# 22102   4070fb9426d56583b18c2bd51655b521
# 25945   cd785d034250181e61281b8ab64798cc
# 31578   f26dcf3500caefeb5a29a6cf17aa86da
# 35162   4070fb9426d56583b18c2bd51655b521
# 46054   4070fb9426d56583b18c2bd51655b521
# 56696   4070fb9426d56583b18c2bd51655b521
# 57041   a1140d1a054f3e3f9d084d6a290a54dd
# 73382   f26dcf3500caefeb5a29a6cf17aa86da
# 76424   4070fb9426d56583b18c2bd51655b521
# 88260   d024359636efee34f3bb75126b180741
# 93154   34bef40403c3cc368bac94794b0695af
# 96292   f26dcf3500caefeb5a29a6cf17aa86da
# 116948  4070fb9426d56583b18c2bd51655b521
# 117008  34bef40403c3cc368bac94794b0695af
# 132316  a1140d1a054f3e3f9d084d6a290a54dd
# 132376  4deb611f9c9cec3309e5c89e9d15428a
# 135715  a1140d1a054f3e3f9d084d6a290a54dd
# 144070  f26dcf3500caefeb5a29a6cf17aa86da
# 151598  a1140d1a054f3e3f9d084d6a290a54dd
# 164534  4deb611f9c9cec3309e5c89e9d15428a
# 166428  f26dcf3500caefeb5a29a6cf17aa86da
# 167676  cd785d034250181e61281b8ab64798cc
# 174044  a1140d1a054f3e3f9d084d6a290a54dd
# 178451  d024359636efee34f3bb75126b180741
# 179006  a1140d1a054f3e3f9d084d6a290a54dd
# 182159  cd785d034250181e61281b8ab64798cc
# 183093  d024359636efee34f3bb75126b180741
# 183990  34bef40403c3cc368bac94794b0695af
# 187893  34bef40403c3cc368bac94794b0695af
# 189347  34bef40403c3cc368bac94794b0695af
# 192135  f26dcf3500caefeb5a29a6cf17aa86da
# 203077  4deb611f9c9cec3309e5c89e9d15428a
# 213046  4deb611f9c9cec3309e5c89e9d15428a
# 216787  cd785d034250181e61281b8ab64798cc
# 217319  a1140d1a054f3e3f9d084d6a290a54dd
# 225705  34bef40403c3cc368bac94794b0695af
# 227484  4070fb9426d56583b18c2bd51655b521
# 235683  4deb611f9c9cec3309e5c89e9d15428a
#
#                                                match_name  \
# 7574    d2cbza1 c.37.1.0 (A:642-871) automated matches...
# 13169   d2ff4a2 a.118.8.3 (A:105-283) Probable regulat...
# 22102   d1g4wr2 c.45.1.2 (R:297-539) SptP tyrosine pho...
# 25945   d6hn1a2 a.126.1.0 (A:196-387) automated matche...
# 31578   d5lhfa_ c.1.2.0 (A:) automated matches {Thermo...
# 35162   d1rp3b_ a.137.11.1 (B:) Anti-sigma factor FlgM...
# 46054   d2z16a1 a.95.1.1 (A:2-158) automated matches {...
# 56696   d1xoua_ a.231.1.1 (A:) Secreted protein EspA {...
# 57041   d1dl2a_ a.102.2.1 (A:) Class I alpha-1;2-manno...
# 73382   d3gr3a_ d.90.1.0 (A:) automated matches {Barto...
# 76424   d1i1ip_ d.92.1.5 (P:) Neurolysin (endopeptidas...
# 88260   d4p82a1 c.61.1.1 (A:2-179) automated matches {...
# 93154   d4ay7a_ c.1.22.0 (A:) automated matches {Metha...
# 96292   d3tlfa_ c.14.1.0 (A:) automated matches {Mycob...
# 116948  d3piua_ c.67.1.4 (A:) 1-aminocyclopropane-1-ca...
# 117008  d1esda_ c.23.10.1 (A:) Esterase {Streptomyces ...
# 132316  d1gwya_ b.97.1.1 (A:) Sticholysin II {Carribea...
# 132376  d6m5na_ c.2.1.0 (A:) automated matches {Pseudo...
# 135715  d1ct9a1 c.26.2.1 (A:193-516) Asparagine synthe...
# 144070  d2vk8a2 c.31.1.0 (A:182-360) automated matches...
# 151598  d1phka_ d.144.1.7 (A:) gamma-subunit of glycog...
# 164534  d3llta_ d.144.1.0 (A:) automated matches {Plas...
# 166428  d3kd6a1 c.72.1.0 (A:2-300) automated matches {...
# 167676  d1wp9a2 c.37.1.19 (A:201-486) putative ATP-dep...
# 174044  d3bila_ c.93.1.0 (A:) automated matches {Coryn...
# 178451  d2aefa2 d.286.1.1 (A:245-336) Potassium channe...
# 179006  d3n0xa_ c.93.1.0 (A:) automated matches {Rhodo...
# 182159  d1ve4a1 c.94.1.1 (A:1-206) ATP phosphoribosylt...
# 183093  d1e5xa_ c.79.1.1 (A:) Threonine synthase {Thal...
# 183990  d3g60a1 f.37.1.1 (A:33-371) P-glycoprotein (P-...
# 187893  d1xt8a1 c.94.1.1 (A:10-257) Putative amino-aci...
# 189347  d1z1aa1 d.339.1.1 (A:484-611) Regulatory prote...
# 192135  d3i44a_ c.82.1.0 (A:) automated matches {Barto...
# 203077  d5ci5a_ c.94.1.0 (A:) automated matches {Pseud...
# 213046  d4ubta1 c.95.1.0 (A:1-268) automated matches {...
# 216787  d4zpca_ e.8.1.4 (A:) automated matches {Coxsac...
# 217319  d5w83b_ c.97.3.1 (B:) Proteasome regulatory su...
# 225705  d5ekza_ e.39.1.0 (A:) automated matches {Mouse...
# 227484  g1sse.1 g.78.1.1 (A:,B:) YAP1 redox domain {Ba...
# 235683  d3by5a1 c.151.1.1 (A:8-130) Cobalamin biosynth...
#
#                                match_md5  containment  max_containment  \
# 7574    2236a5ec50d5c4fed2c6fabc7442c82a     0.020134         0.020134
# 13169   cbda0bce5eb5c9c9c03f5fbfe6d22929     0.017094         0.017094
# 22102   28b5b7a0f8306ebbf4c21bc1ff056829     0.017442         0.017442
# 25945   9d64ab94bbaac3374b4738dc7b8e444f     0.017094         0.017094
# 31578   10ebf71efd24a33dc95526f1f16c7820     0.015152         0.015152
# 35162   da6361abc3ab34a4c70d47507ae1450c     0.017442         0.046875
# 46054   36e9c9541b4b8a152f4a8381a9dbff0d     0.023256         0.029851
# 56696   2ce1011e19790d12eec9a73bb4823238     0.011628         0.014599
# 57041   7222911dca54f82eeaef9605aa5ceeae     0.020134         0.020134
# 73382   44ae5cbf198cff06ac92b853a40c15ce     0.015152         0.015152
# 76424   54e407a85d8689e3b042532d59a66358     0.029070         0.029070
# 88260   2c8e564bd7cc60ce6882c66e2df86d5c     0.014599         0.014599
# 93154   d18af9ec5e122adef697099845351dff     0.027778         0.027778
# 96292   d5db0392a2dd0d1d08bce77af98915b5     0.022727         0.022727
# 116948  efd25ff7de79333a6720aa8cae05c870     0.011628         0.011628
# 117008  c9dec045d3344c99d99b77cf629910fc     0.018519         0.018519
# 132316  c9850e7f24d352cbb5efde569a7e34f7     0.020134         0.020134
# 132376  611a1bb438cc6b79f46ac41f930f50cb     0.024390         0.024390
# 135715  bfa9aac08fb40195dfb1b203b3ca04c0     0.013423         0.013423
# 144070  fd69665419f49860a80925ed0f6831ff     0.022727         0.022727
# 151598  0915334ad70beeed611078f4207e981e     0.013423         0.013423
# 164534  4570bf437904cf06709e51634a2a44e9     0.032520         0.032520
# 166428  e5b3aa96c219219753d9084c4edb27d1     0.022727         0.022727
# 167676  79d560de6cf15069eae21e4572ab8646     0.034188         0.034188
# 174044  ad532f9b108673e3e2437d925cc1d9d9     0.060403         0.060403
# 178451  ad8c19ea050a139650e487751782c667     0.021898         0.043478
# 179006  5416dde48c83732b815735f2f9388ae0     0.020134         0.020134
# 182159  6cbd88d218e4eb462ed64c50df07ec17     0.017094         0.017094
# 183093  92c17d9c9dba13ff6737a3a5f0fe7b90     0.021898         0.021898
# 183990  9905ae8a5a73388f88cd8eafded51f96     0.018519         0.018519
# 187893  860c560aa258f90fc6a7b0607f552e3d     0.027778         0.027778
# 189347  51a26d1a02e9f512183b21dbaf3ccf2c     0.064815         0.066667
# 192135  a4545288360b864abcd42ae1a18a48a8     0.030303         0.030303
# 203077  ef444f8a39f82b416f1be33f453b7083     0.016260         0.016260
# 213046  59b8c48e6398d93eb0102561c197b55c     0.016260         0.016260
# 216787  1306a310c4cfc9ffd4edb2bc9f847579     0.059829         0.059829
# 217319  54a8d00d51425944cfe11c100e3a5c33     0.013423         0.013423
# 225705  d7b607c2e0c15c0cbe92f568d1584bef     0.018519         0.018519
# 227484  ab8e920d6c95298177817f11c6f07de2     0.011628         0.020202
# 235683  a506a09e1a7752ddca92f204bb7e741d     0.016260         0.020000
#
#          jaccard  intersect_hashes  prob_overlap  prob_overlap_adjusted  \
# 7574    0.008499               3.0  1.989487e-12               0.000458
# 13169   0.007380               2.0  1.326325e-12               0.000306
# 22102   0.007712               3.0  1.989487e-12               0.000458
# 25945   0.007042               2.0  1.326325e-12               0.000306
# 31578   0.006349               2.0  1.326325e-12               0.000306
# 35162   0.012876               3.0  3.647393e-12               0.000840
# 46054   0.013245               4.0  2.652650e-12               0.000611
# 56696   0.006515               2.0  1.326325e-12               0.000306
# 57041   0.004732               3.0  4.476346e-12               0.001031
# 73382   0.006006               2.0  1.326325e-12               0.000306
# 76424   0.006180               5.0  5.802671e-12               0.001337
# 88260   0.006897               2.0  1.326325e-12               0.000306
# 93154   0.007160               3.0  1.989487e-12               0.000458
# 96292   0.008043               3.0  1.989487e-12               0.000458
# 116948  0.003552               2.0  1.326325e-12               0.000306
# 117008  0.005195               2.0  2.155278e-12               0.000496
# 132316  0.010067               3.0  3.647393e-12               0.000840
# 132376  0.008427               3.0  1.989487e-12               0.000458
# 135715  0.004464               2.0  2.984231e-12               0.000687
# 144070  0.010526               3.0  4.476346e-12               0.001031
# 151598  0.004988               2.0  1.326325e-12               0.000306
# 164534  0.009153               4.0  2.652650e-12               0.000611
# 166428  0.007407               3.0  1.989487e-12               0.000458
# 167676  0.010638               4.0  3.481603e-12               0.000802
# 174044  0.023316               9.0  8.455320e-12               0.001948
# 178451  0.014778               3.0  1.989487e-12               0.000458
# 179006  0.006073               3.0  2.818440e-12               0.000649
# 182159  0.006711               2.0  2.984231e-12               0.000687
# 183093  0.005102               3.0  1.989487e-12               0.000458
# 183990  0.004739               2.0  1.326325e-12               0.000306
# 187893  0.009091               3.0  2.818440e-12               0.000649
# 189347  0.033981               7.0  5.471090e-12               0.001260
# 192135  0.006885               4.0  5.139509e-12               0.001184
# 203077  0.004073               2.0  1.326325e-12               0.000306
# 213046  0.005464               2.0  1.326325e-12               0.000306
# 216787  0.012750               7.0  6.300043e-12               0.001451
# 217319  0.006192               2.0  1.326325e-12               0.000306
# 225705  0.006579               2.0  1.326325e-12               0.000306
# 227484  0.007435               2.0  2.155278e-12               0.000496
# 235683  0.009050               2.0  1.326325e-12               0.000306
#
#         containment_adjusted  containment_adjusted_log10  tf_idf_score  \
# 7574               43.936148                    1.642822      0.191859
# 13169              55.952872                    1.747822      0.162889
# 22102              38.060965                    1.580480      0.166203
# 25945              55.952872                    1.747822      0.162889
# 31578              49.594591                    1.695434      0.144379
# 35162              20.760526                    1.317238      0.162858
# 46054              38.060965                    1.580480      0.221604
# 56696              38.060965                    1.580480      0.110802
# 57041              19.527177                    1.290639      0.186067
# 73382              49.594591                    1.695434      0.144379
# 76424              21.749123                    1.337442      0.271988
# 88260              47.784569                    1.679288      0.139109
# 93154              60.615611                    1.782584      0.264694
# 96292              49.594591                    1.695434      0.216568
# 116948             38.060965                    1.580480      0.110802
# 117008             37.301915                    1.571731      0.173799
# 132316             23.965171                    1.379581      0.187997
# 132376             53.223463                    1.726103      0.232414
# 135715             19.527177                    1.290639      0.124044
# 144070             22.042040                    1.343252      0.210030
# 151598             43.936148                    1.642822      0.127906
# 164534             53.223463                    1.726103      0.309886
# 166428             49.594591                    1.695434      0.216568
# 167676             42.630759                    1.629723      0.323319
# 174044             31.013751                    1.491554      0.569784
# 178451             47.784569                    1.679288      0.208664
# 179006             31.013751                    1.491554      0.189928
# 182159             24.867943                    1.395640      0.157971
# 183093             47.784569                    1.679288      0.208664
# 183990             60.615611                    1.782584      0.176463
# 187893             42.787490                    1.631317      0.262030
# 189347             51.431428                    1.711229      0.614956
# 192135             25.597208                    1.408193      0.282219
# 203077             53.223463                    1.726103      0.154943
# 213046             53.223463                    1.726103      0.154943
# 216787             41.228432                    1.615197      0.565193
# 217319             43.936148                    1.642822      0.127906
# 225705             60.615611                    1.782584      0.176463
# 227484             23.422132                    1.369626      0.109130
# 235683             53.223463                    1.726103      0.154943
#
#        query_scop_id query_scop_lineage query_scop_lineage_fixed query_family  \
# 7574         d1ohua_            f.1.4.1                  f.1.4.1      f.1.4.1
# 13169        d7jgwa1            f.1.4.1                  f.1.4.1      f.1.4.1
# 22102        d1ddba_            f.1.4.1                  f.1.4.1      f.1.4.1
# 25945        d7jgwa1            f.1.4.1                  f.1.4.1      f.1.4.1
# 31578        d6udva_            f.1.4.1                  f.1.4.1      f.1.4.1
# 35162        d1ddba_            f.1.4.1                  f.1.4.1      f.1.4.1
# 46054        d1ddba_            f.1.4.1                  f.1.4.1      f.1.4.1
# 56696        d1ddba_            f.1.4.1                  f.1.4.1      f.1.4.1
# 57041        d1ohua_            f.1.4.1                  f.1.4.1      f.1.4.1
# 73382        d6udva_            f.1.4.1                  f.1.4.1      f.1.4.1
# 76424        d1ddba_            f.1.4.1                  f.1.4.1      f.1.4.1
# 88260        d1q59a1            f.1.4.1                  f.1.4.1      f.1.4.1
# 93154        d3bl2a_            f.1.4.1                  f.1.4.1      f.1.4.1
# 96292        d6udva_            f.1.4.1                  f.1.4.1      f.1.4.1
# 116948       d1ddba_            f.1.4.1                  f.1.4.1      f.1.4.1
# 117008       d3bl2a_            f.1.4.1                  f.1.4.1      f.1.4.1
# 132316       d1ohua_            f.1.4.1                  f.1.4.1      f.1.4.1
# 132376       d1k3ka_            f.1.4.1                  f.1.4.1      f.1.4.1
# 135715       d1ohua_            f.1.4.1                  f.1.4.1      f.1.4.1
# 144070       d6udva_            f.1.4.1                  f.1.4.1      f.1.4.1
# 151598       d1ohua_            f.1.4.1                  f.1.4.1      f.1.4.1
# 164534       d1k3ka_            f.1.4.1                  f.1.4.1      f.1.4.1
# 166428       d6udva_            f.1.4.1                  f.1.4.1      f.1.4.1
# 167676       d7jgwa1            f.1.4.1                  f.1.4.1      f.1.4.1
# 174044       d1ohua_            f.1.4.1                  f.1.4.1      f.1.4.1
# 178451       d1q59a1            f.1.4.1                  f.1.4.1      f.1.4.1
# 179006       d1ohua_            f.1.4.1                  f.1.4.1      f.1.4.1
# 182159       d7jgwa1            f.1.4.1                  f.1.4.1      f.1.4.1
# 183093       d1q59a1            f.1.4.1                  f.1.4.1      f.1.4.1
# 183990       d3bl2a_            f.1.4.1                  f.1.4.1      f.1.4.1
# 187893       d3bl2a_            f.1.4.1                  f.1.4.1      f.1.4.1
# 189347       d3bl2a_            f.1.4.1                  f.1.4.1      f.1.4.1
# 192135       d6udva_            f.1.4.1                  f.1.4.1      f.1.4.1
# 203077       d1k3ka_            f.1.4.1                  f.1.4.1      f.1.4.1
# 213046       d1k3ka_            f.1.4.1                  f.1.4.1      f.1.4.1
# 216787       d7jgwa1            f.1.4.1                  f.1.4.1      f.1.4.1
# 217319       d1ohua_            f.1.4.1                  f.1.4.1      f.1.4.1
# 225705       d3bl2a_            f.1.4.1                  f.1.4.1      f.1.4.1
# 227484       d1ddba_            f.1.4.1                  f.1.4.1      f.1.4.1
# 235683       d1k3ka_            f.1.4.1                  f.1.4.1      f.1.4.1
#
#        query_superfamily query_fold query_class match_scop_id  \
# 7574               f.1.4        f.1           f       d2cbza1
# 13169              f.1.4        f.1           f       d2ff4a2
# 22102              f.1.4        f.1           f       d1g4wr2
# 25945              f.1.4        f.1           f       d6hn1a2
# 31578              f.1.4        f.1           f       d5lhfa_
# 35162              f.1.4        f.1           f       d1rp3b_
# 46054              f.1.4        f.1           f       d2z16a1
# 56696              f.1.4        f.1           f       d1xoua_
# 57041              f.1.4        f.1           f       d1dl2a_
# 73382              f.1.4        f.1           f       d3gr3a_
# 76424              f.1.4        f.1           f       d1i1ip_
# 88260              f.1.4        f.1           f       d4p82a1
# 93154              f.1.4        f.1           f       d4ay7a_
# 96292              f.1.4        f.1           f       d3tlfa_
# 116948             f.1.4        f.1           f       d3piua_
# 117008             f.1.4        f.1           f       d1esda_
# 132316             f.1.4        f.1           f       d1gwya_
# 132376             f.1.4        f.1           f       d6m5na_
# 135715             f.1.4        f.1           f       d1ct9a1
# 144070             f.1.4        f.1           f       d2vk8a2
# 151598             f.1.4        f.1           f       d1phka_
# 164534             f.1.4        f.1           f       d3llta_
# 166428             f.1.4        f.1           f       d3kd6a1
# 167676             f.1.4        f.1           f       d1wp9a2
# 174044             f.1.4        f.1           f       d3bila_
# 178451             f.1.4        f.1           f       d2aefa2
# 179006             f.1.4        f.1           f       d3n0xa_
# 182159             f.1.4        f.1           f       d1ve4a1
# 183093             f.1.4        f.1           f       d1e5xa_
# 183990             f.1.4        f.1           f       d3g60a1
# 187893             f.1.4        f.1           f       d1xt8a1
# 189347             f.1.4        f.1           f       d1z1aa1
# 192135             f.1.4        f.1           f       d3i44a_
# 203077             f.1.4        f.1           f       d5ci5a_
# 213046             f.1.4        f.1           f       d4ubta1
# 216787             f.1.4        f.1           f       d4zpca_
# 217319             f.1.4        f.1           f       d5w83b_
# 225705             f.1.4        f.1           f       d5ekza_
# 227484             f.1.4        f.1           f       g1sse.1
# 235683             f.1.4        f.1           f       d3by5a1
#
#        match_scop_lineage match_scop_lineage_fixed match_family  \
# 7574             c.37.1.0                 c.37.1.0     c.37.1.0
# 13169           a.118.8.3                a.118.8.3    a.118.8.3
# 22102            c.45.1.2                 c.45.1.2     c.45.1.2
# 25945           a.126.1.0                a.126.1.0    a.126.1.0
# 31578             c.1.2.0                  c.1.2.0      c.1.2.0
# 35162          a.137.11.1               a.137.11.1   a.137.11.1
# 46054            a.95.1.1                 a.95.1.1     a.95.1.1
# 56696           a.231.1.1                a.231.1.1    a.231.1.1
# 57041           a.102.2.1                a.102.2.1    a.102.2.1
# 73382            d.90.1.0                 d.90.1.0     d.90.1.0
# 76424            d.92.1.5                 d.92.1.5     d.92.1.5
# 88260            c.61.1.1                 c.61.1.1     c.61.1.1
# 93154            c.1.22.0                 c.1.22.0     c.1.22.0
# 96292            c.14.1.0                 c.14.1.0     c.14.1.0
# 116948           c.67.1.4                 c.67.1.4     c.67.1.4
# 117008          c.23.10.1                c.23.10.1    c.23.10.1
# 132316           b.97.1.1                 b.97.1.1     b.97.1.1
# 132376            c.2.1.0                  c.2.1.0      c.2.1.0
# 135715           c.26.2.1                 c.26.2.1     c.26.2.1
# 144070           c.31.1.0                 c.31.1.0     c.31.1.0
# 151598          d.144.1.7                d.144.1.7    d.144.1.7
# 164534          d.144.1.0                d.144.1.0    d.144.1.0
# 166428           c.72.1.0                 c.72.1.0     c.72.1.0
# 167676          c.37.1.19                c.37.1.19    c.37.1.19
# 174044           c.93.1.0                 c.93.1.0     c.93.1.0
# 178451          d.286.1.1                d.286.1.1    d.286.1.1
# 179006           c.93.1.0                 c.93.1.0     c.93.1.0
# 182159           c.94.1.1                 c.94.1.1     c.94.1.1
# 183093           c.79.1.1                 c.79.1.1     c.79.1.1
# 183990           f.37.1.1                 f.37.1.1     f.37.1.1
# 187893           c.94.1.1                 c.94.1.1     c.94.1.1
# 189347          d.339.1.1                d.339.1.1    d.339.1.1
# 192135           c.82.1.0                 c.82.1.0     c.82.1.0
# 203077           c.94.1.0                 c.94.1.0     c.94.1.0
# 213046           c.95.1.0                 c.95.1.0     c.95.1.0
# 216787            e.8.1.4                  e.8.1.4      e.8.1.4
# 217319           c.97.3.1                 c.97.3.1     c.97.3.1
# 225705           e.39.1.0                 e.39.1.0     e.39.1.0
# 227484           g.78.1.1                 g.78.1.1     g.78.1.1
# 235683          c.151.1.1                c.151.1.1    c.151.1.1
#
#        match_superfamily match_fold match_class  same_family  \
# 7574              c.37.1       c.37           c        False
# 13169            a.118.8      a.118           a        False
# 22102             c.45.1       c.45           c        False
# 25945            a.126.1      a.126           a        False
# 31578              c.1.2        c.1           c        False
# 35162           a.137.11      a.137           a        False
# 46054             a.95.1       a.95           a        False
# 56696            a.231.1      a.231           a        False
# 57041            a.102.2      a.102           a        False
# 73382             d.90.1       d.90           d        False
# 76424             d.92.1       d.92           d        False
# 88260             c.61.1       c.61           c        False
# 93154             c.1.22        c.1           c        False
# 96292             c.14.1       c.14           c        False
# 116948            c.67.1       c.67           c        False
# 117008           c.23.10       c.23           c        False
# 132316            b.97.1       b.97           b        False
# 132376             c.2.1        c.2           c        False
# 135715            c.26.2       c.26           c        False
# 144070            c.31.1       c.31           c        False
# 151598           d.144.1      d.144           d        False
# 164534           d.144.1      d.144           d        False
# 166428            c.72.1       c.72           c        False
# 167676            c.37.1       c.37           c        False
# 174044            c.93.1       c.93           c        False
# 178451           d.286.1      d.286           d        False
# 179006            c.93.1       c.93           c        False
# 182159            c.94.1       c.94           c        False
# 183093            c.79.1       c.79           c        False
# 183990            f.37.1       f.37           f        False
# 187893            c.94.1       c.94           c        False
# 189347           d.339.1      d.339           d        False
# 192135            c.82.1       c.82           c        False
# 203077            c.94.1       c.94           c        False
# 213046            c.95.1       c.95           c        False
# 216787             e.8.1        e.8           e        False
# 217319            c.97.3       c.97           c        False
# 225705            e.39.1       e.39           e        False
# 227484            g.78.1       g.78           g        False
# 235683           c.151.1      c.151           c        False
#
#         same_superfamily  same_fold  same_class  family  superfamily   fold  \
# 7574               False      False       False   False        False  False
# 13169              False      False       False   False        False  False
# 22102              False      False       False   False        False  False
# 25945              False      False       False   False        False  False
# 31578              False      False       False   False        False  False
# 35162              False      False       False   False        False  False
# 46054              False      False       False   False        False  False
# 56696              False      False       False   False        False  False
# 57041              False      False       False   False        False  False
# 73382              False      False       False   False        False  False
# 76424              False      False       False   False        False  False
# 88260              False      False       False   False        False  False
# 93154              False      False       False   False        False  False
# 96292              False      False       False   False        False  False
# 116948             False      False       False   False        False  False
# 117008             False      False       False   False        False  False
# 132316             False      False       False   False        False  False
# 132376             False      False       False   False        False  False
# 135715             False      False       False   False        False  False
# 144070             False      False       False   False        False  False
# 151598             False      False       False   False        False  False
# 164534             False      False       False   False        False  False
# 166428             False      False       False   False        False  False
# 167676             False      False       False   False        False  False
# 174044             False      False       False   False        False  False
# 178451             False      False       False   False        False  False
# 179006             False      False       False   False        False  False
# 182159             False      False       False   False        False  False
# 183093             False      False       False   False        False  False
# 183990             False      False        True   False        False  False
# 187893             False      False       False   False        False  False
# 189347             False      False       False   False        False  False
# 192135             False      False       False   False        False  False
# 203077             False      False       False   False        False  False
# 213046             False      False       False   False        False  False
# 216787             False      False       False   False        False  False
# 217319             False      False       False   False        False  False
# 225705             False      False       False   False        False  False
# 227484             False      False       False   False        False  False
# 235683             False      False       False   False        False  False
#
#         class
# 7574    False
# 13169   False
# 22102   False
# 25945   False
# 31578   False
# 35162   False
# 46054   False
# 56696   False
# 57041   False
# 73382   False
# 76424   False
# 88260   False
# 93154   False
# 96292   False
# 116948  False
# 117008  False
# 132316  False
# 132376  False
# 135715  False
# 144070  False
# 151598  False
# 164534  False
# 166428  False
# 167676  False
# 174044  False
# 178451  False
# 179006  False
# 182159  False
# 183093  False
# 183990   True
# 187893  False
# 189347  False
# 192135  False
# 203077  False
# 213046  False
# 216787  False
# 217319  False
# 225705  False
# 227484  False
# 235683  False

# %%
foldseek_scop_rocx.query("FP < 1")
# Out:
#              SCOP  FAM  SFAM  FOLD  FP  FAMCNT  SFAMCNT  FOLDCNT
# NAME
# d2ciob_  b.1.26.0  0.0   0.0   0.0   0       1        3      402

# %%
multisearch_no_self.head()
# Out:
#                                           query_name  \
# 1  d2q4gw_ c.10.1.1 (W:) automated matches {Human...
# 2  d2dita1 d.58.7.1 (A:8-106) HIV Tat-specific fa...
# 3  d4xmra1 d.110.6.4 (A:41-285) Cj1564 {Campyloba...
# 4  d1m1jb1 d.171.1.1 (B:200-464) Fibrinogen C-ter...
# 5  d1v5va2 d.250.1.1 (A:3-312) Glycine cleavage s...
#
#                           query_md5  \
# 1  896c4441aae821222649f6c1f64eecd7
# 2  101ca324b2f0c3e29ad8f6e020339df3
# 3  80b412d0452551ff3286100baacfa109
# 4  0072d84134578f4b85fdc79718d81ed0
# 5  f0227b386b4e8fe1535708eebe3b4bdc
#
#                                           match_name  \
# 1  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...
# 2  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...
# 3  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...
# 4  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...
# 5  d4j42a_ a.25.3.0 (A:) automated matches {Bacil...
#
#                           match_md5  containment  max_containment   jaccard  \
# 1  2927928970a388981b12f1dba1be85b5     0.002288         0.017544  0.002028
# 2  2927928970a388981b12f1dba1be85b5     0.052632         0.070175  0.031008
# 3  2927928970a388981b12f1dba1be85b5     0.004505         0.017544  0.003597
# 4  2927928970a388981b12f1dba1be85b5     0.004132         0.017544  0.003356
# 5  2927928970a388981b12f1dba1be85b5     0.006969         0.035088  0.005848
#
#    intersect_hashes  prob_overlap  prob_overlap_adjusted  \
# 1               1.0  6.631624e-13               0.000153
# 2               4.0  2.652650e-12               0.000611
# 3               1.0  6.631624e-13               0.000153
# 4               1.0  6.631624e-13               0.000153
# 5               2.0  1.326325e-12               0.000306
#
#    containment_adjusted  containment_adjusted_log10  tf_idf_score  \
# 1             14.980517                    1.175527      0.021805
# 2             86.137974                    1.935195      0.501526
# 3             29.488676                    1.469655      0.042923
# 4             27.051595                    1.432193      0.039376
# 5             22.810056                    1.358126      0.066404
#
#   query_scop_id query_scop_lineage query_scop_lineage_fixed query_family  \
# 1       d2q4gw_           c.10.1.1                 c.10.1.1     c.10.1.1
# 2       d2dita1           d.58.7.1                 d.58.7.1     d.58.7.1
# 3       d4xmra1          d.110.6.4                d.110.6.4    d.110.6.4
# 4       d1m1jb1          d.171.1.1                d.171.1.1    d.171.1.1
# 5       d1v5va2          d.250.1.1                d.250.1.1    d.250.1.1
#
#   query_superfamily query_fold query_class match_scop_id match_scop_lineage  \
# 1            c.10.1       c.10           c       d4j42a_           a.25.3.0
# 2            d.58.7       d.58           d       d4j42a_           a.25.3.0
# 3           d.110.6      d.110           d       d4j42a_           a.25.3.0
# 4           d.171.1      d.171           d       d4j42a_           a.25.3.0
# 5           d.250.1      d.250           d       d4j42a_           a.25.3.0
#
#   match_scop_lineage_fixed match_family match_superfamily match_fold  \
# 1                 a.25.3.0     a.25.3.0            a.25.3       a.25
# 2                 a.25.3.0     a.25.3.0            a.25.3       a.25
# 3                 a.25.3.0     a.25.3.0            a.25.3       a.25
# 4                 a.25.3.0     a.25.3.0            a.25.3       a.25
# 5                 a.25.3.0     a.25.3.0            a.25.3       a.25
#
#   match_class  same_family  same_superfamily  same_fold  same_class  family  \
# 1           a        False             False      False       False   False
# 2           a        False             False      False       False   False
# 3           a        False             False      False       False   False
# 4           a        False             False      False       False   False
# 5           a        False             False      False       False   False
#
#    superfamily   fold  class
# 1        False  False  False
# 2        False  False  False
# 3        False  False  False
# 4        False  False  False
# 5        False  False  False

# %%
# (
#     multisearch_zero_self_spurious.groupby(["query_scop_id", "query_family"])[
#         same_scop_cols
#     ].sum()
#     - 1
# )

# %%
same_scop_counts = multisearch_zero_self_spurious.groupby(
    ["query_scop_id"] + query_scop_cols, observed=True
)[same_scop_cols].sum()

# Subtract 1 for self-matches
# Doing this after the fact makes sure that we have ALL 15,177 samples for
# each analyses, otherwise they'd be unobserved
same_scop_counts -= 1

same_scop_bool = same_scop_counts > 0
same_scop_bool.columns = same_scop_bool.columns + "_bool"
same_scop_counts = pd.concat([same_scop_counts, same_scop_bool], axis=1)
same_scop_counts.head()
# Out:
#                                                                      same_family  \
# query_scop_id query_family query_superfamily query_fold query_class
# d12asa_       d.104.1.1    d.104.1           d.104      d                      0
# d16vpa_       d.180.1.1    d.180.1           d.180      d                      0
# d1914a1       d.49.1.1     d.49.1            d.49       d                      0
# d1914a2       d.49.1.1     d.49.1            d.49       d                      0
# d1a04a1       a.4.6.2      a.4.6             a.4        a                      0
#
#                                                                      same_superfamily  \
# query_scop_id query_family query_superfamily query_fold query_class
# d12asa_       d.104.1.1    d.104.1           d.104      d                           0
# d16vpa_       d.180.1.1    d.180.1           d.180      d                           0
# d1914a1       d.49.1.1     d.49.1            d.49       d                           0
# d1914a2       d.49.1.1     d.49.1            d.49       d                           1
# d1a04a1       a.4.6.2      a.4.6             a.4        a                           0
#
#                                                                      same_fold  \
# query_scop_id query_family query_superfamily query_fold query_class
# d12asa_       d.104.1.1    d.104.1           d.104      d                    0
# d16vpa_       d.180.1.1    d.180.1           d.180      d                    0
# d1914a1       d.49.1.1     d.49.1            d.49       d                    0
# d1914a2       d.49.1.1     d.49.1            d.49       d                    1
# d1a04a1       a.4.6.2      a.4.6             a.4        a                    0
#
#                                                                      same_class  \
# query_scop_id query_family query_superfamily query_fold query_class
# d12asa_       d.104.1.1    d.104.1           d.104      d                     4
# d16vpa_       d.180.1.1    d.180.1           d.180      d                     7
# d1914a1       d.49.1.1     d.49.1            d.49       d                     1
# d1914a2       d.49.1.1     d.49.1            d.49       d                     1
# d1a04a1       a.4.6.2      a.4.6             a.4        a                     0
#
#                                                                      same_family_bool  \
# query_scop_id query_family query_superfamily query_fold query_class
# d12asa_       d.104.1.1    d.104.1           d.104      d                       False
# d16vpa_       d.180.1.1    d.180.1           d.180      d                       False
# d1914a1       d.49.1.1     d.49.1            d.49       d                       False
# d1914a2       d.49.1.1     d.49.1            d.49       d                       False
# d1a04a1       a.4.6.2      a.4.6             a.4        a                       False
#
#                                                                      same_superfamily_bool  \
# query_scop_id query_family query_superfamily query_fold query_class
# d12asa_       d.104.1.1    d.104.1           d.104      d                            False
# d16vpa_       d.180.1.1    d.180.1           d.180      d                            False
# d1914a1       d.49.1.1     d.49.1            d.49       d                            False
# d1914a2       d.49.1.1     d.49.1            d.49       d                             True
# d1a04a1       a.4.6.2      a.4.6             a.4        a                            False
#
#                                                                      same_fold_bool  \
# query_scop_id query_family query_superfamily query_fold query_class
# d12asa_       d.104.1.1    d.104.1           d.104      d                     False
# d16vpa_       d.180.1.1    d.180.1           d.180      d                     False
# d1914a1       d.49.1.1     d.49.1            d.49       d                     False
# d1914a2       d.49.1.1     d.49.1            d.49       d                      True
# d1a04a1       a.4.6.2      a.4.6             a.4        a                     False
#
#                                                                      same_class_bool
# query_scop_id query_family query_superfamily query_fold query_class
# d12asa_       d.104.1.1    d.104.1           d.104      d                       True
# d16vpa_       d.180.1.1    d.180.1           d.180      d                       True
# d1914a1       d.49.1.1     d.49.1            d.49       d                       True
# d1914a2       d.49.1.1     d.49.1            d.49       d                       True
# d1a04a1       a.4.6.2      a.4.6             a.4        a                      False

# %%
same_scop_counts_reset = same_scop_counts.reset_index(level=[1, 2, 3, 4])
same_scop_counts_reset.head()
# Out:
#               query_family query_superfamily query_fold query_class  \
# query_scop_id
# d12asa_          d.104.1.1           d.104.1      d.104           d
# d16vpa_          d.180.1.1           d.180.1      d.180           d
# d1914a1           d.49.1.1            d.49.1       d.49           d
# d1914a2           d.49.1.1            d.49.1       d.49           d
# d1a04a1            a.4.6.2             a.4.6        a.4           a
#
#                same_family  same_superfamily  same_fold  same_class  \
# query_scop_id
# d12asa_                  0                 0          0           4
# d16vpa_                  0                 0          0           7
# d1914a1                  0                 0          0           1
# d1914a2                  0                 1          1           1
# d1a04a1                  0                 0          0           0
#
#                same_family_bool  same_superfamily_bool  same_fold_bool  \
# query_scop_id
# d12asa_                   False                  False           False
# d16vpa_                   False                  False           False
# d1914a1                   False                  False           False
# d1914a2                   False                   True            True
# d1a04a1                   False                  False           False
#
#                same_class_bool
# query_scop_id
# d12asa_                   True
# d16vpa_                   True
# d1914a1                   True
# d1914a2                   True
# d1a04a1                  False

# %%
# same_scop_counts[same_scop_cols].value_counts()

# %%
def count_scop_lineage(df, col):
    return Counter([df[col].cat.categories[i] for i in df[col].cat.codes])


n_groups_per_scop_lineage = {
    lineage: count_scop_lineage(multisearch_no_self, f"query_{lineage}")
    for lineage in lineage_cols
}
n_groups_per_scop_lineage.keys()
# n_groups_per_scop_lineage
# Out:
# dict_keys(['family', 'superfamily', 'fold', 'class'])

# %%
def get_sensitivity_per_scop_lineage(
    row, n_groups_per_scop_lineage=n_groups_per_scop_lineage
):
    percentages = {}
    for lineage, counts in n_groups_per_scop_lineage.items():
        ql = f"query_{lineage}"
        divisor = counts[row[ql]] - 1
        if divisor > 0:
            percentage = row[f"same_{lineage}"] / divisor
        else:
            percentage = 0
        percentages[lineage] = percentage
    return pd.Series(percentages)


same_scop_sensitivity = same_scop_counts_reset.apply(
    get_sensitivity_per_scop_lineage, axis=1
)
# same_scop_sensitivity.columns = "same_" + same_scop_percentage.columns + "_sensitivity"
same_scop_sensitivity
# Out:
#                family  superfamily  fold     class
# query_scop_id
# d12asa_           0.0         0.00  0.00  0.000092
# d16vpa_           0.0         0.00  0.00  0.000162
# d1914a1           0.0         0.00  0.00  0.000023
# d1914a2           0.0         0.05  0.05  0.000023
# d1a04a1           0.0         0.00  0.00  0.000000
# ...               ...          ...   ...       ...
# g2dbx.1           0.0         0.00  0.00  0.000277
# g2vt1.1           0.0         0.00  0.00  0.000046
# g3bzy.1           0.0         0.00  0.00  0.000000
# g3n55.1           0.0         0.00  0.00  0.000095
# g6rlx.1           0.0         0.00  0.00  0.000000
#
# [15169 rows x 4 columns]

# %%
same_scop_sensitivity.max()
# Out:
# family         0.200000
# superfamily    0.125000
# fold           0.100000
# class          0.006374
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
fraction_queries = pd.Series(
    np.linspace(0, 1, num=len(same_scop_sensitivity)), name="fraction_queries"
)

plt.plot(fraction_queries, same_scop_sensitivity["family"].sort_values(ascending=False))

# %%
same_scop_combined = pd.concat(
    [
        same_scop_counts_reset,
        same_scop_sensitivity,
    ],
    axis=1,
)
same_scop_combined.head()
# Out:
#               query_family query_superfamily query_fold query_class  \
# query_scop_id
# d12asa_          d.104.1.1           d.104.1      d.104           d
# d16vpa_          d.180.1.1           d.180.1      d.180           d
# d1914a1           d.49.1.1            d.49.1       d.49           d
# d1914a2           d.49.1.1            d.49.1       d.49           d
# d1a04a1            a.4.6.2             a.4.6        a.4           a
#
#                same_family  same_superfamily  same_fold  same_class  \
# query_scop_id
# d12asa_                  0                 0          0           4
# d16vpa_                  0                 0          0           7
# d1914a1                  0                 0          0           1
# d1914a2                  0                 1          1           1
# d1a04a1                  0                 0          0           0
#
#                same_family_bool  same_superfamily_bool  same_fold_bool  \
# query_scop_id
# d12asa_                   False                  False           False
# d16vpa_                   False                  False           False
# d1914a1                   False                  False           False
# d1914a2                   False                   True            True
# d1a04a1                   False                  False           False
#
#                same_class_bool  family  superfamily  fold     class
# query_scop_id
# d12asa_                   True     0.0         0.00  0.00  0.000092
# d16vpa_                   True     0.0         0.00  0.00  0.000162
# d1914a1                   True     0.0         0.00  0.00  0.000023
# d1914a2                   True     0.0         0.05  0.05  0.000023
# d1a04a1                  False     0.0         0.00  0.00  0.000000

# %%
sns.displot(same_scop_percentage, cumulative=True, kind="kde")

# %%
# %debug

# %%
# def get_percentage_found(

# true_positive_rate = multisearch_no_self.groupby("query_class").apply(
#     lambda x: x["class"].sum() / lineage_class_value_counts[x.name]
# )
# true_positive_rate

# %%
# false_positive_rate = multisearch_no_self.groupby("query_class").apply(
#     lambda x: x["class"].sum() / lineage_class_value_counts[x.name]
# )
# false_positive_rate

# %%
multisearch_no_self["class"].value_counts()
# Out:
# class
# True     20644
# False    17832
# Name: count, dtype: int64

# %% [markdown]
# ### Show Example Classification Report

# %%
y_true = multisearch_no_self["query_class"]
y_pred = multisearch_no_self["match_class"]
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    multilabel_confusion_matrix,
    precision_recall_fscore_support,
)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.35      0.35      0.35      5091
#            b       0.41      0.41      0.41      4574
#            c       0.68      0.68      0.68     19011
#            d       0.45      0.45      0.45      7356
#            e       0.29      0.29      0.29      1472
#            f       0.20      0.20      0.20       741
#            g       0.35      0.35      0.35       231
#
#     accuracy                           0.54     38476
#    macro avg       0.39      0.39      0.39     38476
# weighted avg       0.54      0.54      0.54     38476

# %%
# Out:
# (array([0.34727951, 0.41407958, 0.68339382, 0.45323545, 0.28940217,
#         0.20242915, 0.34632035]),
#  array([0.34727951, 0.41407958, 0.68339382, 0.45323545, 0.28940217,
#         0.20242915, 0.34632035]),
#  array([0.34727951, 0.41407958, 0.68339382, 0.45323545, 0.28940217,
#         0.20242915, 0.34632035]),
#  array([ 5091,  4574, 19011,  7356,  1472,   741,   231]))

# %%
# classification_report??
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
precision, recall, thresholds = precision_recall_curve(
    multisearch_no_self["class"], multisearch_no_self.containment
)

# %%
sns.relplot(x=recall, y=precision)

# %% [markdown]
# ### PrecisionRecallDisplay

# %%
PrecisionRecallDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.containment
)

# %%
PrecisionRecallDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.prob_overlap_adjusted
)

# %%
PrecisionRecallDisplay.from_predictions(
    multisearch_no_self["class"], 1 / multisearch_no_self.prob_overlap_adjusted
)

# %%
PrecisionRecallDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.containment_adjusted_log10
)

# %%
PrecisionRecallDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.tf_idf_score
)

# %% [markdown]
# ### RocCurveDisplay

# %%
RocCurveDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.containment
)

# %%
RocCurveDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.containment_adjusted_log10
)

# %%
RocCurveDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.tf_idf_score
)

# %% [markdown]
# ### DetCurveDisplay

# %%
DetCurveDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.containment
)

# %%
DetCurveDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.containment_adjusted_log10
)

# %%
DetCurveDisplay.from_predictions(
    multisearch_no_self["class"], multisearch_no_self.tf_idf_score
)

# %% [markdown]
# ## Compute precision-recall, ROC, DET curves

# %%
from typing import Literal

score_cols = (
    "containment",
    "tf_idf_score",
    "containment_adjusted_log10",
    "prob_overlap_adjusted",
)

dfs = []


def make_precision_recall_curve_df(y_true, y_score):
    precision, recall, thresholds = precision_recall_curve(y_true, y_score)
    # Add a dummy value to thresholds so all the arrays are the same length
    thresholds = np.concat([thresholds, [thresholds.max()]])
    df = pd.DataFrame(dict(precision=precision, recall=recall, thresholds=thresholds))
    return df


def make_roc_curve_df(y_true, y_score):
    fpr, tpr, thresholds = roc_curve(y_true, y_score)
    df = pd.DataFrame(dict(fpr=fpr, tpr=tpr, thresholds=thresholds))
    return df


def make_det_curve_df(y_true, y_score):
    fpr, fnr, thresholds = det_curve(y_true, y_score)
    df = pd.DataFrame(dict(fpr=fpr, fnr=fnr, thresholds=thresholds))
    return df


curve_df_makers = {
    "precision_recall": make_precision_recall_curve_df,
    "roc": make_roc_curve_df,
    "det": make_det_curve_df,
}


def make_curve_df(
    y_true,
    y_score,
    lineage,
    score_name,
    curve: Literal["precision_recall", "roc", "det"],
):
    df_maker = curve_df_makers[curve]
    df = df_maker(y_true, y_score)
    df["lineage"] = lineage_col
    df["score_name"] = score_col
    return df


curve_dfs = {
    "precision_recall": [],
    "roc": [],
    "det": [],
}

lines = []


for lineage_col in lineage_cols:
    for score_col in score_cols:
        y_true = multisearch_no_self[lineage_col]
        # y_true = multisearch_no_self[lineage_col]
        y_score = multisearch_no_self[score_col]

        ap_score = average_precision_score(y_true, y_score)
        roc_score = roc_auc_score(y_true, y_score)

        lines.append([lineage_col, score_col, ap_score, "average_precision"])
        lines.append([lineage_col, score_col, roc_score, "roc"])

        for curve in curve_df_makers.keys():
            df = make_curve_df(y_true, y_score, lineage_col, score_col, curve)

            curve_dfs[curve].append(df)
classification_metrics = pd.DataFrame(
    lines, columns=["lineage", "sourmash_score", "metric", "metric_name"]
)
classification_metrics
# Out:
#         lineage              sourmash_score    metric        metric_name
# 0        family                 containment  0.311685  average_precision
# 1        family                 containment  0.631559                roc
# 2        family                tf_idf_score  0.303030  average_precision
# 3        family                tf_idf_score  0.618050                roc
# 4        family  containment_adjusted_log10  0.132928  average_precision
# 5        family  containment_adjusted_log10  0.300670                roc
# 6        family       prob_overlap_adjusted  0.459467  average_precision
# 7        family       prob_overlap_adjusted  0.787603                roc
# 8   superfamily                 containment  0.507712  average_precision
# 9   superfamily                 containment  0.652650                roc
# 10  superfamily                tf_idf_score  0.493654  average_precision
# 11  superfamily                tf_idf_score  0.635536                roc
# 12  superfamily  containment_adjusted_log10  0.228840  average_precision
# 13  superfamily  containment_adjusted_log10  0.270107                roc
# 14  superfamily       prob_overlap_adjusted  0.770488  average_precision
# 15  superfamily       prob_overlap_adjusted  0.836331                roc
# 16         fold                 containment  0.510127  average_precision
# 17         fold                 containment  0.649301                roc
# 18         fold                tf_idf_score  0.496305  average_precision
# 19         fold                tf_idf_score  0.632457                roc
# 20         fold  containment_adjusted_log10  0.234546  average_precision
# 21         fold  containment_adjusted_log10  0.272628                roc
# 22         fold       prob_overlap_adjusted  0.767973  average_precision
# 23         fold       prob_overlap_adjusted  0.831636                roc
# 24        class                 containment  0.616617  average_precision
# 25        class                 containment  0.568671                roc
# 26        class                tf_idf_score  0.608825  average_precision
# 27        class                tf_idf_score  0.558534                roc
# 28        class  containment_adjusted_log10  0.436601  average_precision
# 29        class  containment_adjusted_log10  0.334581                roc
# 30        class       prob_overlap_adjusted  0.745637  average_precision
# 31        class       prob_overlap_adjusted  0.713203                roc

# %% [markdown]
# ### Show Example Classification Report

# %%
y_true = multisearch_no_self["query_class"]
y_pred = multisearch_no_self["match_class"]
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    multilabel_confusion_matrix,
)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            a       1.00      1.00      1.00        10
#            b       1.00      1.00      1.00         8
#            c       1.00      1.00      1.00         8
#            d       1.00      1.00      1.00         2
#            e       1.00      1.00      1.00         2
#            g       1.00      1.00      1.00         2
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32

# %% [markdown]
# ### Show Confusion Matrix

# %%
confusion_matrix(y_true, y_pred)
# Out:
# array([[10,  0,  0,  0,  0,  0],
#        [ 0,  8,  0,  0,  0,  0],
#        [ 0,  0,  8,  0,  0,  0],
#        [ 0,  0,  0,  2,  0,  0],
#        [ 0,  0,  0,  0,  2,  0],
#        [ 0,  0,  0,  0,  0,  2]])

# %%
sns.catplot(
    data=classification_metrics,
    x="metric",
    hue="lineage",
    y="sourmash_score",
    col="metric_name",
    kind="bar",
    # palette="Set2",
)

# %%
len(curve_dfs["precision_recall"])
# Out:
# 16

# %%
precision_recall_df = pd.concat(curve_dfs["precision_recall"])
print(precision_recall_df.shape)
precision_recall_df.head()
# Out:
# (45524, 5)
#    precision    recall  thresholds lineage   score_name
# 0   0.190145  1.000000    0.000603  family  containment
# 1   0.190188  0.999863    0.000669  family  containment
# 2   0.190290  0.999727    0.000693  family  containment
# 3   0.190350  0.999727    0.000795  family  containment
# 4   0.190370  0.999727    0.000833  family  containment

# %%
det_df = pd.concat(curve_dfs["det"])
print(det_df.shape)
det_df.head()
# Out:
# (44706, 5)
#         fpr       fnr  thresholds lineage   score_name
# 0  1.000000  0.000000    0.000603  family  containment
# 1  0.999583  0.000137    0.000669  family  containment
# 2  0.998780  0.000273    0.000693  family  containment
# 3  0.998395  0.000273    0.000795  family  containment
# 4  0.998267  0.000273    0.000833  family  containment

# %%
roc_df = pd.concat(curve_dfs["roc"])
print(roc_df.shape)
roc_df.head()
# Out:
# (35302, 5)
#         fpr       tpr  thresholds lineage   score_name
# 0  0.000000  0.000000         inf  family  containment
# 1  0.000064  0.000410    1.000000  family  containment
# 2  0.000064  0.000683    0.833333  family  containment
# 3  0.000096  0.000683    0.818182  family  containment
# 4  0.000096  0.001914    0.170543  family  containment

# %% [markdown]
# ## Plot curves across SCOP lineages and sourmash match scores (containment, tf-idf score, adjusted containment, probability of overlap)

# %% [markdown]
# ### Plot Precision Recall

# %%
g = sns.relplot(
    data=precision_recall_df,
    x="recall",
    y="precision",
    hue="lineage",
    col="score_name",
    height=3,
    col_wrap=2,
    kind="line",
)
g.set_titles("{col_name}")

# %% [markdown]
# ### Plot ROC AUC

# %%
g = sns.relplot(
    data=roc_df,
    x="fpr",
    y="tpr",
    hue="lineage",
    col="score_name",
    height=3,
    col_wrap=2,
    kind="line",
)
g.set_titles("{col_name}")

# %% [markdown]
# ### Plot DET Curve

# %%
g = sns.relplot(
    data=det_df,
    x="fpr",
    y="fnr",
    hue="lineage",
    col="score_name",
    height=3,
    col_wrap=2,
    kind="line",
)
g.set_titles("{col_name}")

# %% [markdown]
# # Compute metrics across all ksizes

# %%
# %%file evaluate_sourmash_multisearch.py

curve_dfs = {
    "precision_recall": [],
    "roc": [],
    "det": [],
}

lines = []


def make_curve_df_ksize_moltype(
    y_true,
    y_score,
    lineage,
    sourmash_score,
    curve: Literal["precision_recall", "roc", "det"],
    ksize: int,
    moltype: Literal["protein", "dayhoff", "hp"],
):
    df_maker = curve_df_makers[curve]
    df = df_maker(y_true, y_score)
    df["lineage"] = lineage_col
    df["sourmash_score"] = score_col
    df["moltype"] = moltype
    df["ksize"] = ksize
    return df


moltype = "protein"


binary_classification_scorers = {
    "average_precision": average_precision_score,
    "roc_auc": roc_auc_score,
    # "top_k_accuracy": top_k_accuracy_score,
}

multiclass_scorers = {
    "recall": lambda x, y: recall_score(x, y, average="macro"),
    "f1": lambda x, y: f1_score(x, y, average="macro"),
    "balanced_accuracy": balanced_accuracy_score,
    "accuracy": accuracy_score,
    # "top_k_accuracy": top_k_accuracy_score,
}

confusion_matrices = {}


def make_score_line(
    y_true, y_pred, sklearn_score_name, lineage, sourmash_score_name, ksize, moltype
):
    try:
        scorer = binary_classification_scorers[sklearn_score_name]
    except KeyError:
        scorer = multiclass_scorers[sklearn_score_name]
    score_value = scorer(y_true, y_pred)
    line = [
        moltype,
        ksize,
        lineage,
        sourmash_score_name,
        score_value,
        sklearn_score_name,
    ]
    return line


def make_precision_recall_fscore_support_df(
    y_true, y_pred, lineage, sourmash_score_name, ksize, moltype
):
    p, r, f, s = precision_recall_fscore_support(y_true, y_pred, average="macro")

    df = pd.DataFrame(dict(precision=p, recall=r, fscore=f, support=s))
    df["lineage"] = lineage
    df["sourmash_score"] = sourmash_score_name
    df["moltype"] = moltype
    df["ksize"] = ksize
    return df


lines = []
ksizes = range(7, 21)
for ksize in ksizes:
    print(f"--- ksize: {ksize} ---")
    pq = make_multisearch_pq(ksize, analysis_outdir, "protein")
    multisearch = pd.read_parquet(pq)
    # Take the inverse of probability of overlap, so that bigger is better
    multisearch["prob_overlap_adjusted"] = 1 / multisearch["prob_overlap_adjusted"]

    lineage_cols = ["family", "superfamily", "fold", "class"]

    for lineage_col in lineage_cols:
        query = f"query_{lineage_col}"
        match = f"match_{lineage_col}"

        multisearch[lineage_col] = multisearch[query] == multisearch[match]

    # Ignore self matches
    print(f"Before removing self-matches: {multisearch.shape}")
    multisearch_no_self = multisearch.query("query_name != match_name")
    print(f"After  removing self-matches: {multisearch_no_self.shape}")

    for lineage_col in lineage_cols:
        for sourmash_score_name in score_cols:
            y_true_bool = multisearch_no_self[lineage_col]

            y_true = multisearch_no_self[f"query_{lineage_col}"]
            y_pred = multisearch_no_self[f"match_{lineage_col}"]
            y_score = multisearch_no_self[sourmash_score_name]

            for sklearn_score in binary_classification_scorers.keys():
                try:
                    line = make_score_line(
                        y_true_bool,
                        y_score,
                        sklearn_score,
                        lineage_col,
                        sourmash_score_name,
                        ksize,
                        moltype,
                    )
                    lines.append(line)
                except ValueError:
                    # skip when ROC isn't defined, when only one class is present
                    pass

            for sklearn_score in multiclass_scorers.keys():
                # try:
                line = make_score_line(
                    y_true,
                    y_pred,
                    sklearn_score,
                    lineage_col,
                    sourmash_score_name,
                    ksize,
                    moltype,
                )
                lines.append(line)
                # except ValueError:
                #     # skip when ROC isn't defined, when only one class is present
                #     pass

            matrix = confusion_matrix(y_true, y_pred)
            key = (moltype, ksize, sourmash_score_name, lineage_col)
            confusion_matrices[key] = matrix

            for curve in curve_df_makers.keys():
                try:
                    with warnings.catch_warnings(action="ignore"):
                        # Ignore warnings that show up only one class in y_true
                        # UndefinedMetricWarning: No negative samples in y_true,
                        # false positive value should be meaningless
                        df = make_curve_df_ksize_moltype(
                            y_true_bool,
                            y_score,
                            lineage_col,
                            sourmash_score_name,
                            curve,
                            ksize,
                            moltype,
                        )

                        curve_dfs[curve].append(df)
                except ValueError:
                    # skip when ROC or DET aren't defined, when only one class is present
                    pass

classification_metrics = pd.DataFrame(
    lines,
    columns=["moltype", "ksize", "lineage", "sourmash_score", "metric", "metric_name"],
)
classification_metrics
# Out:
# Writing evaluate_sourmash_multisearch.py

# %%
classification_metrics.metric_name.value_counts()
# Out:
# metric_name
# average_precision    224
# recall               224
# balanced_accuracy    224
# f1                   224
# accuracy             224
# roc_auc              188
# Name: count, dtype: int64

# %%
classification_metrics
# Out:
#       moltype  ksize lineage         sourmash_score    metric  \
# 0     protein      7  family            containment  0.311685
# 1     protein      7  family            containment  0.631559
# 2     protein      7  family            containment  0.049119
# 3     protein      7  family            containment  0.049119
# 4     protein      7  family            containment  0.049119
# ...       ...    ...     ...                    ...       ...
# 1303  protein     20   class  prob_overlap_adjusted  1.000000
# 1304  protein     20   class  prob_overlap_adjusted  1.000000
# 1305  protein     20   class  prob_overlap_adjusted  1.000000
# 1306  protein     20   class  prob_overlap_adjusted  1.000000
# 1307  protein     20   class  prob_overlap_adjusted  1.000000
#
#             metric_name
# 0     average_precision
# 1               roc_auc
# 2                recall
# 3                    f1
# 4     balanced_accuracy
# ...                 ...
# 1303  average_precision
# 1304             recall
# 1305                 f1
# 1306  balanced_accuracy
# 1307           accuracy
#
# [1308 rows x 6 columns]

# %%
sns.catplot(
    data=classification_metrics,
    x="metric",
    hue="ksize",
    y="sourmash_score",
    col="lineage",
    row="metric_name",
    kind="bar",
    # palette="Set2",
)

# %%
classification_metrics.query('metric_name != "roc_auc"').groupby(
    ["metric_name", "lineage", "sourmash_score"]
).apply(lambda x: x.nlargest(1, "metric"))
# Out:
# /tmp/ipykernel_11181/2541944322.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ).apply(lambda x: x.nlargest(1, "metric"))
#                                                          moltype  ksize  \
# metric_name lineage     sourmash_score
# accuracy    class       containment                1124  protein     18
#                         containment_adjusted_log10 1134  protein     18
#                         prob_overlap_adjusted      1139  protein     18
#                         tf_idf_score               1129  protein     18
#             family      containment                965   protein     17
# ...                                                          ...    ...
# recall      fold        tf_idf_score               1106  protein     18
#             superfamily containment                1081  protein     18
#                         containment_adjusted_log10 1091  protein     18
#                         prob_overlap_adjusted      1096  protein     18
#                         tf_idf_score               1086  protein     18
#
#                                                              lineage  \
# metric_name lineage     sourmash_score
# accuracy    class       containment                1124        class
#                         containment_adjusted_log10 1134        class
#                         prob_overlap_adjusted      1139        class
#                         tf_idf_score               1129        class
#             family      containment                965        family
# ...                                                              ...
# recall      fold        tf_idf_score               1106         fold
#             superfamily containment                1081  superfamily
#                         containment_adjusted_log10 1091  superfamily
#                         prob_overlap_adjusted      1096  superfamily
#                         tf_idf_score               1086  superfamily
#
#                                                                      sourmash_score  \
# metric_name lineage     sourmash_score
# accuracy    class       containment                1124                 containment
#                         containment_adjusted_log10 1134  containment_adjusted_log10
#                         prob_overlap_adjusted      1139       prob_overlap_adjusted
#                         tf_idf_score               1129                tf_idf_score
#             family      containment                965                  containment
# ...                                                                             ...
# recall      fold        tf_idf_score               1106                tf_idf_score
#             superfamily containment                1081                 containment
#                         containment_adjusted_log10 1091  containment_adjusted_log10
#                         prob_overlap_adjusted      1096       prob_overlap_adjusted
#                         tf_idf_score               1086                tf_idf_score
#
#                                                          metric metric_name
# metric_name lineage     sourmash_score
# accuracy    class       containment                1124     1.0    accuracy
#                         containment_adjusted_log10 1134     1.0    accuracy
#                         prob_overlap_adjusted      1139     1.0    accuracy
#                         tf_idf_score               1129     1.0    accuracy
#             family      containment                965      0.7    accuracy
# ...                                                         ...         ...
# recall      fold        tf_idf_score               1106     1.0      recall
#             superfamily containment                1081     1.0      recall
#                         containment_adjusted_log10 1091     1.0      recall
#                         prob_overlap_adjusted      1096     1.0      recall
#                         tf_idf_score               1086     1.0      recall
#
# [80 rows x 6 columns]

# %%
classification_metrics.query('metric_name == "roc_auc"').groupby(
    ["metric_name", "lineage", "sourmash_score"]
).apply(lambda x: x.nsmallest(1, "metric"))
# Out:
# /tmp/ipykernel_11181/2943551036.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ).apply(lambda x: x.nsmallest(1, "metric"))
#                                                          moltype  ksize  \
# metric_name lineage     sourmash_score
# roc_auc     class       containment                649   protein     13
#                         containment_adjusted_log10 373   protein     10
#                         prob_overlap_adjusted      1051  protein     17
#                         tf_idf_score               655   protein     13
#             family      containment                385   protein     11
#                         containment_adjusted_log10 13    protein      7
#                         prob_overlap_adjusted      19    protein      7
#                         tf_idf_score               391   protein     11
#             fold        containment                625   protein     13
#                         containment_adjusted_log10 349   protein     10
#                         prob_overlap_adjusted      1027  protein     17
#                         tf_idf_score               631   protein     13
#             superfamily containment                601   protein     13
#                         containment_adjusted_log10 325   protein     10
#                         prob_overlap_adjusted      1003  protein     17
#                         tf_idf_score               607   protein     13
#
#                                                              lineage  \
# metric_name lineage     sourmash_score
# roc_auc     class       containment                649         class
#                         containment_adjusted_log10 373         class
#                         prob_overlap_adjusted      1051        class
#                         tf_idf_score               655         class
#             family      containment                385        family
#                         containment_adjusted_log10 13         family
#                         prob_overlap_adjusted      19         family
#                         tf_idf_score               391        family
#             fold        containment                625          fold
#                         containment_adjusted_log10 349          fold
#                         prob_overlap_adjusted      1027         fold
#                         tf_idf_score               631          fold
#             superfamily containment                601   superfamily
#                         containment_adjusted_log10 325   superfamily
#                         prob_overlap_adjusted      1003  superfamily
#                         tf_idf_score               607   superfamily
#
#                                                                      sourmash_score  \
# metric_name lineage     sourmash_score
# roc_auc     class       containment                649                  containment
#                         containment_adjusted_log10 373   containment_adjusted_log10
#                         prob_overlap_adjusted      1051       prob_overlap_adjusted
#                         tf_idf_score               655                 tf_idf_score
#             family      containment                385                  containment
#                         containment_adjusted_log10 13    containment_adjusted_log10
#                         prob_overlap_adjusted      19         prob_overlap_adjusted
#                         tf_idf_score               391                 tf_idf_score
#             fold        containment                625                  containment
#                         containment_adjusted_log10 349   containment_adjusted_log10
#                         prob_overlap_adjusted      1027       prob_overlap_adjusted
#                         tf_idf_score               631                 tf_idf_score
#             superfamily containment                601                  containment
#                         containment_adjusted_log10 325   containment_adjusted_log10
#                         prob_overlap_adjusted      1003       prob_overlap_adjusted
#                         tf_idf_score               607                 tf_idf_score
#
#                                                            metric metric_name
# metric_name lineage     sourmash_score
# roc_auc     class       containment                649   0.230769     roc_auc
#                         containment_adjusted_log10 373   0.262665     roc_auc
#                         prob_overlap_adjusted      1051  0.103448     roc_auc
#                         tf_idf_score               655   0.230769     roc_auc
#             family      containment                385   0.474112     roc_auc
#                         containment_adjusted_log10 13    0.300670     roc_auc
#                         prob_overlap_adjusted      19    0.212397     roc_auc
#                         tf_idf_score               391   0.471396     roc_auc
#             fold        containment                625   0.230769     roc_auc
#                         containment_adjusted_log10 349   0.269734     roc_auc
#                         prob_overlap_adjusted      1027  0.103448     roc_auc
#                         tf_idf_score               631   0.230769     roc_auc
#             superfamily containment                601   0.230769     roc_auc
#                         containment_adjusted_log10 325   0.269734     roc_auc
#                         prob_overlap_adjusted      1003  0.103448     roc_auc
#                         tf_idf_score               607   0.230769     roc_auc

# %% [markdown]
# ## Concatenate curve dataframes

# %%
precision_recall_df = pd.concat(curve_dfs["precision_recall"])
print(precision_recall_df.shape)
precision_recall_df.head()
# Out:
# (116160, 7)
#    precision    recall  thresholds lineage         sourmash_score  moltype  \
# 0   0.190145  1.000000    0.000603  family  prob_overlap_adjusted  protein
# 1   0.190188  0.999863    0.000669  family  prob_overlap_adjusted  protein
# 2   0.190290  0.999727    0.000693  family  prob_overlap_adjusted  protein
# 3   0.190350  0.999727    0.000795  family  prob_overlap_adjusted  protein
# 4   0.190370  0.999727    0.000833  family  prob_overlap_adjusted  protein
#
#    ksize
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7

# %%
det_df = pd.concat(curve_dfs["det"])
print(det_df.shape)
det_df.head()
# Out:
# (109677, 7)
#         fpr       fnr  thresholds lineage         sourmash_score  moltype  \
# 0  1.000000  0.000000    0.000603  family  prob_overlap_adjusted  protein
# 1  0.999583  0.000137    0.000669  family  prob_overlap_adjusted  protein
# 2  0.998780  0.000273    0.000693  family  prob_overlap_adjusted  protein
# 3  0.998395  0.000273    0.000795  family  prob_overlap_adjusted  protein
# 4  0.998267  0.000273    0.000833  family  prob_overlap_adjusted  protein
#
#    ksize
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7

# %%
roc_df = pd.concat(curve_dfs["roc"])
print(roc_df.shape)
roc_df.head()
# Out:
# (80654, 7)
#         fpr       tpr  thresholds lineage         sourmash_score  moltype  \
# 0  0.000000  0.000000         inf  family  prob_overlap_adjusted  protein
# 1  0.000064  0.000410    1.000000  family  prob_overlap_adjusted  protein
# 2  0.000064  0.000683    0.833333  family  prob_overlap_adjusted  protein
# 3  0.000096  0.000683    0.818182  family  prob_overlap_adjusted  protein
# 4  0.000096  0.001914    0.170543  family  prob_overlap_adjusted  protein
#
#    ksize
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7

# %% [markdown]
# ## Plot curves across SCOP lineages and sourmash match scores (containment, tf-idf score, adjusted containment, probability of overlap)

# %% [markdown]
# ### Plot Precision Recall

# %%
precision_recall_df.query('lineage == "family"').sourmash_score.value_counts()
# Out:
# sourmash_score
# prob_overlap_adjusted    29040
# Name: count, dtype: int64

# %%
g = sns.relplot(
    data=precision_recall_df.query('lineage == "family"'),
    x="recall",
    y="precision",
    hue="ksize",
    col="sourmash_score",
    height=3,
    col_wrap=2,
    # kind="line",
)
g.set_titles("{col_name}")

# %% [markdown]
# ### Plot ROC AUC

# %%
g = sns.relplot(
    data=precision_recall_df.query('lineage == "family"'),
    x="fpr",
    y="tpr",
    hue="ksize",
    col="sourmash_score",
    height=3,
    col_wrap=2,
    kind="line",
)
g.set_titles("{col_name}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 g = sns.relplot(
#       2     data=precision_recall_df.query('lineage == "family"'),
#       3     x="fpr",
#       4     y="tpr",
#       5     hue="ksize",
#       6     col="sourmash_score",
#       7     height=3,
#       8     col_wrap=2,
#       9     kind="line",
#      10 )
#      11 g.set_titles("{col_name}")
#
# File ~/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/seaborn/relational.py:748, in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     746         msg = "The `weights` parameter has no effect with kind='scatter'."
#     747         warnings.warn(msg, stacklevel=2)
# --> 748 p = Plotter(
#     749     data=data,
#     750     variables=variables,
#     751     legend=legend,
#     752 )
#     753 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     754 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/seaborn/relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/miniconda3/envs/2024-kmerseek-analysis-polars/lib/python3.12/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `fpr` for `x`. An entry with this name does not appear in `data`.

# %% [markdown]
# ### Plot DET Curve

# %%
g = sns.relplot(
    data=det_df,
    x="fpr",
    y="fnr",
    hue="lineage",
    col="score_name",
    height=3,
    col_wrap=2,
    kind="line",
)
g.set_titles("{col_name}")
